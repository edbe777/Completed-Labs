# %%
### data ###
import numpy as np
import pandas as pd

### visualization ###
#!pip install chart_studio
import chart_studio.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px

### utilities ###
import datetime
import warnings
from scipy import stats
import statsmodels.api as sm
pd.set_option('display.max_columns', None)
import pandas_profiling
import sweetviz as sv

### file format ###
import csv
import xml.etree.ElementTree as ET
warnings.filterwarnings("ignore")
import pickle
import json
import requests

### machine learning ###
import random
from sklearn import cluster
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import KFold
from sklearn import cluster, datasets
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
#!pip install lazypredict
#import lazypredict
#from lazypredict.Supervised import LazyClassifier
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("U.S._Chronic_Disease_Indicators_CDI.csv", sep=',')

# %%
df.shape
# Out:
# (956638, 34)

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
#lowercase
df.columns = [columns.lower().replace(' ', '_') for columns in df.columns]  
df.columns
# Out:
# Index(['yearstart', 'yearend', 'locationabbr', 'locationdesc', 'datasource',
#        'topic', 'question', 'response', 'datavalueunit', 'datavaluetype',
#        'datavalue', 'datavaluealt', 'datavaluefootnotesymbol',
#        'datavaluefootnote', 'lowconfidencelimit', 'highconfidencelimit',
#        'stratificationcategory1', 'stratification1', 'stratificationcategory2',
#        'stratification2', 'stratificationcategory3', 'stratification3',
#        'geolocation', 'responseid', 'locationid', 'topicid', 'questionid',
#        'datavaluetypeid', 'stratificationcategoryid1', 'stratificationid1',
#        'stratificationcategoryid2', 'stratificationid2',
#        'stratificationcategoryid3', 'stratificationid3'],
#       dtype='object')

# %%
df.head()
# Out:
#    yearstart  yearend locationabbr locationdesc         datasource   topic  \
# 0       2010     2014           AK       Alaska  Death Certificate  Cancer
# 1       2010     2014           AK       Alaska  Death Certificate  Cancer
# 2       2010     2014           AZ      Arizona  Death Certificate  Cancer
# 3       2008     2012           NY     New York  Death Certificate  Cancer
# 4       2009     2013           NY     New York  Death Certificate  Cancer
#
#                                            question  response datavalueunit  \
# 0  Cancer of the oral cavity and pharynx, mortality       NaN           NaN
# 1  Cancer of the oral cavity and pharynx, mortality       NaN           NaN
# 2  Cancer of the oral cavity and pharynx, mortality       NaN           NaN
# 3  Cancer of the oral cavity and pharynx, mortality       NaN           NaN
# 4  Cancer of the oral cavity and pharynx, mortality       NaN           NaN
#
#            datavaluetype datavalue  datavaluealt datavaluefootnotesymbol  \
# 0  Average Annual Number         3           3.0                     NaN
# 1  Average Annual Number        15          15.0                     NaN
# 2  Average Annual Number       109         109.0                     NaN
# 3  Average Annual Number       329         329.0                     NaN
# 4  Average Annual Number       336         336.0                     NaN
#
#   datavaluefootnote  lowconfidencelimit  highconfidencelimit  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#   stratificationcategory1 stratification1  stratificationcategory2  \
# 0                  Gender          Female                      NaN
# 1                 Overall         Overall                      NaN
# 2                  Gender            Male                      NaN
# 3                  Gender            Male                      NaN
# 4                  Gender            Male                      NaN
#
#    stratification2  stratificationcategory3  stratification3  \
# 0              NaN                      NaN              NaN
# 1              NaN                      NaN              NaN
# 2              NaN                      NaN              NaN
# 3              NaN                      NaN              NaN
# 4              NaN                      NaN              NaN
#
#                         geolocation  responseid  locationid topicid  \
# 0   POINT (-147.722059 64.84507996)         NaN           2     CAN
# 1   POINT (-147.722059 64.84507996)         NaN           2     CAN
# 2  POINT (-111.7638113 34.86597028)         NaN           4     CAN
# 3  POINT (-75.54397043 42.82700103)         NaN          36     CAN
# 4  POINT (-75.54397043 42.82700103)         NaN          36     CAN
#
#   questionid datavaluetypeid stratificationcategoryid1 stratificationid1  \
# 0    CAN10_2      AVGANNNMBR                    GENDER              GENF
# 1    CAN10_2      AVGANNNMBR                   OVERALL               OVR
# 2    CAN10_2      AVGANNNMBR                    GENDER              GENM
# 3    CAN10_2      AVGANNNMBR                    GENDER              GENM
# 4    CAN10_2      AVGANNNMBR                    GENDER              GENM
#
#    stratificationcategoryid2  stratificationid2  stratificationcategoryid3  \
# 0                        NaN                NaN                        NaN
# 1                        NaN                NaN                        NaN
# 2                        NaN                NaN                        NaN
# 3                        NaN                NaN                        NaN
# 4                        NaN                NaN                        NaN
#
#    stratificationid3
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956638 entries, 0 to 956637
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   yearstart                  956638 non-null  int64
#  1   yearend                    956638 non-null  int64
#  2   locationabbr               956638 non-null  object
#  3   locationdesc               956638 non-null  object
#  4   datasource                 956638 non-null  object
#  5   topic                      956638 non-null  object
#  6   question                   956638 non-null  object
#  7   response                   0 non-null       float64
#  8   datavalueunit              830938 non-null  object
#  9   datavaluetype              956638 non-null  object
#  10  datavalue                  646040 non-null  object
#  11  datavaluealt               644213 non-null  float64
#  12  datavaluefootnotesymbol    323640 non-null  object
#  13  datavaluefootnote          323640 non-null  object
#  14  lowconfidencelimit         548944 non-null  float64
#  15  highconfidencelimit        548944 non-null  float64
#  16  stratificationcategory1    956638 non-null  object
#  17  stratification1            956638 non-null  object
#  18  stratificationcategory2    0 non-null       float64
#  19  stratification2            0 non-null       float64
#  20  stratificationcategory3    0 non-null       float64
#  21  stratification3            0 non-null       float64
#  22  geolocation                948566 non-null  object
#  23  responseid                 0 non-null       float64
#  24  locationid                 956638 non-null  int64
#  25  topicid                    956638 non-null  object
#  26  questionid                 956638 non-null  object
#  27  datavaluetypeid            956638 non-null  object
#  28  stratificationcategoryid1  956638 non-null  object
#  29  stratificationid1          956638 non-null  object
#  30  stratificationcategoryid2  0 non-null       float64
#  31  stratificationid2          0 non-null       float64
#  32  stratificationcategoryid3  0 non-null       float64
#  33  stratificationid3          0 non-null       float64
# dtypes: float64(13), int64(3), object(18)
# memory usage: 248.2+ MB

# %%
#columns with missing data
missing = (df.isnull().sum())
print(missing[missing > 0])
# Out:
# response                     956638
# datavalueunit                125700
# datavalue                    310598
# datavaluealt                 312425
# datavaluefootnotesymbol      632998
# datavaluefootnote            632998
# lowconfidencelimit           407694
# highconfidencelimit          407694
# stratificationcategory2      956638
# stratification2              956638
# stratificationcategory3      956638
# stratification3              956638
# geolocation                    8072
# responseid                   956638
# stratificationcategoryid2    956638
# stratificationid2            956638
# stratificationcategoryid3    956638
# stratificationid3            956638
# dtype: int64

# %%
# check how much each column is filled
(df.count()/len(df))*100
# Out:
# yearstart                    100.000000
# yearend                      100.000000
# locationabbr                 100.000000
# locationdesc                 100.000000
# datasource                   100.000000
# topic                        100.000000
# question                     100.000000
# response                       0.000000
# datavalueunit                 86.860233
# datavaluetype                100.000000
# datavalue                     67.532337
# datavaluealt                  67.341356
# datavaluefootnotesymbol       33.830979
# datavaluefootnote             33.830979
# lowconfidencelimit            57.382625
# highconfidencelimit           57.382625
# stratificationcategory1      100.000000
# stratification1              100.000000
# stratificationcategory2        0.000000
# stratification2                0.000000
# stratificationcategory3        0.000000
# stratification3                0.000000
# geolocation                   99.156212
# responseid                     0.000000
# locationid                   100.000000
# topicid                      100.000000
# questionid                   100.000000
# datavaluetypeid              100.000000
# stratificationcategoryid1    100.000000
# stratificationid1            100.000000
# stratificationcategoryid2      0.000000
# stratificationid2              0.000000
# stratificationcategoryid3      0.000000
# stratificationid3              0.000000
# dtype: float64

# %%
df = df.drop(['response','stratificationcategory2','stratification2','stratificationcategory3','stratification3','responseid','stratificationcategoryid2','stratificationid2','stratificationcategoryid3','stratificationid3'], axis=1)

# %%
df.describe()
# Out:
#            yearstart        yearend  datavaluealt  lowconfidencelimit  \
# count  956638.000000  956638.000000  6.442130e+05       548944.000000
# mean     2014.171975    2014.674424  1.027406e+03           51.354871
# std         2.828787       2.464271  1.950444e+04           88.619162
# min      2001.000000    2001.000000  0.000000e+00            0.000000
# 25%      2012.000000    2013.000000  1.750000e+01           12.000000
# 50%      2014.000000    2015.000000  4.100000e+01           29.500000
# 75%      2017.000000    2017.000000  7.629000e+01           56.900000
# max      2020.000000    2020.000000  2.892731e+06         1615.700000
#
#        highconfidencelimit     locationid
# count        548944.000000  956638.000000
# mean             63.338942      30.815676
# std              99.479634      17.526069
# min               0.080000       1.000000
# 25%              17.800000      17.000000
# 50%              42.400000      30.000000
# 75%              71.600000      45.000000
# max            2137.000000      78.000000

# %%
# check how much each column is filled
(df.count()/len(df))*100
# Out:
# yearstart                    100.000000
# yearend                      100.000000
# locationabbr                 100.000000
# locationdesc                 100.000000
# datasource                   100.000000
# topic                        100.000000
# question                     100.000000
# datavalueunit                 86.860233
# datavaluetype                100.000000
# datavalue                     67.532337
# datavaluealt                  67.341356
# datavaluefootnotesymbol       33.830979
# datavaluefootnote             33.830979
# lowconfidencelimit            57.382625
# highconfidencelimit           57.382625
# stratificationcategory1      100.000000
# stratification1              100.000000
# geolocation                   99.156212
# locationid                   100.000000
# topicid                      100.000000
# questionid                   100.000000
# datavaluetypeid              100.000000
# stratificationcategoryid1    100.000000
# stratificationid1            100.000000
# dtype: float64

# %%
# how many questions and in which categories
print("number of questions: " + str(df.question.nunique()))
print("number of categories: " + str(df.stratificationcategory1.nunique()))
# Out:
# number of questions: 203
# number of categories: 3

# %%
df.stratificationcategory1.unique()
# Out:
# array(['Gender', 'Overall', 'Race/Ethnicity'], dtype=object)

# %%
gender = df.loc[df.stratificationcategory1 == 'Gender']
overall = df.loc[df.stratificationcategory1 == 'Overall']
race_ethnicity = df.loc[df.stratificationcategory1 == 'Race/Ethnicity']

# %%
#a big overview of the data
def df_values(df):
    for i in range(0, len(df.columns)):
        print('----------', df.columns[i], '---------')
        print (df.iloc[:,i].value_counts())
        print ('----------', df.columns[i], '---------- \n')
df_values(df)
# Out:
# ---------- yearstart ---------
# 2013    118802
# 2015    106118
# 2012    103685
# 2017    103150
# 2011    102693
# 2014     96793
# 2016     96484
# 2018     78674
# 2019     59744
# 2010     49705
# 2009     20500
# 2008     20076
# 2001       104
# 2020        55
# 2007        55
# Name: yearstart, dtype: int64
# ---------- yearstart ----------
#
# ---------- yearend ---------
# 2015    126086
# 2017    123118
# 2013    118802
# 2014    116761
# 2016    116122
# 2012    104015
# 2011     82615
# 2018     79004
# 2019     59744
# 2010     29737
# 2009       312
# 2008       108
# 2001       104
# 2020        55
# 2007        55
# Name: yearend, dtype: int64
# ---------- yearend ----------
#
# ---------- locationabbr ---------
# NY    18247
# WI    18247
# NJ    18247
# NE    18212
# VT    18205
# IA    18172
# WV    18148
# WA    18148
# NM    18148
# HI    18120
# MI    18113
# CO    18108
# KY    18072
# UT    18043
# MA    18043
# AR    18043
# NC    18037
# OR    18008
# MD    18008
# RI    18008
# NV    18002
# FL    18002
# SC    18002
# AZ    17997
# SD    17973
# MO    17854
# IL    17854
# DE    17854
# PA    17854
# AK    17854
# ME    17854
# WY    17849
# OK    17819
# CA    17798
# MS    17791
# NH    17784
# CT    17779
# TN    17749
# VA    17749
# LA    17744
# AL    17714
# MN    17714
# OH    17714
# TX    17679
# ND    17679
# KS    17679
# GA    17677
# MT    17644
# ID    17609
# IN    17604
# DC    17604
# PR    11743
# VI    11508
# GU    11459
# US     8072
# Name: locationabbr, dtype: int64
# ---------- locationabbr ----------
#
# ---------- locationdesc ---------
# New Jersey              18247
# Wisconsin               18247
# New York                18247
# Nebraska                18212
# Vermont                 18205
# Iowa                    18172
# New Mexico              18148
# West Virginia           18148
# Washington              18148
# Hawaii                  18120
# Michigan                18113
# Colorado                18108
# Kentucky                18072
# Utah                    18043
# Massachusetts           18043
# Arkansas                18043
# North Carolina          18037
# Rhode Island            18008
# Oregon                  18008
# Maryland                18008
# South Carolina          18002
# Florida                 18002
# Nevada                  18002
# Arizona                 17997
# South Dakota            17973
# Pennsylvania            17854
# Illinois                17854
# Delaware                17854
# Maine                   17854
# Missouri                17854
# Alaska                  17854
# Wyoming                 17849
# Oklahoma                17819
# California              17798
# Mississippi             17791
# New Hampshire           17784
# Connecticut             17779
# Virginia                17749
# Tennessee               17749
# Louisiana               17744
# Minnesota               17714
# Ohio                    17714
# Alabama                 17714
# Texas                   17679
# Kansas                  17679
# North Dakota            17679
# Georgia                 17677
# Montana                 17644
# Idaho                   17609
# District of Columbia    17604
# Indiana                 17604
# Puerto Rico             11743
# Virgin Islands          11508
# Guam                    11459
# United States            8072
# Name: locationdesc, dtype: int64
# ---------- locationdesc ----------
#
# ---------- datasource ---------
# BRFSS                                                     540875
# NVSS                                                      141105
# Death Certificate                                          59904
# Statewide central cancer registries                        59904
# State Inpatient Data                                       45798
# CMS Part A Claims Data                                     44928
# SEDD; SID                                                  18522
# YRBSS                                                      12978
# PRAMS                                                      10135
# ACS 1-Year Estimates                                        9270
# CMS CCW                                                     2592
# USRDS                                                       1664
# STATE                                                       1357
# CDC School Health Profiles                                  1040
# NSCH                                                         990
# APIS                                                         648
# CDC Breastfeeding Report Card                                603
# HRSA, UDS                                                    440
# USDA National Farmers' Market Directory                      440
# National Immunization Survey                                 440
# ACS 5-Year Estimates                                         424
# Current Population Survey                                    424
# NVSS, Mortality                                              416
# ASHW                                                         320
# Legal Research                                               275
# AEDS                                                         220
# WFRS                                                         220
# CDC Children's Food Environment State Indicator Report       214
# ANRF                                                         165
# mPINC                                                        165
# InfoUSA; USDA                                                110
# Birth Certificate, NVSS                                       52
# Name: datasource, dtype: int64
# ---------- datasource ----------
#
# ---------- topic ---------
# Cancer                                             133908
# Cardiovascular Disease                             128676
# Diabetes                                           128654
# Chronic Obstructive Pulmonary Disease              127350
# Asthma                                              64719
# Arthritis                                           62640
# Nutrition, Physical Activity, and Weight Status     61397
# Overarching Conditions                              60365
# Alcohol                                             53220
# Tobacco                                             47669
# Older Adults                                        20784
# Chronic Kidney Disease                              20537
# Oral Health                                         17564
# Mental Health                                       10810
# Immunization                                         7830
# Reproductive Health                                  6858
# Disability                                           3657
# Name: topic, dtype: int64
# ---------- topic ----------
#
# ---------- question ---------
# Hospitalization for chronic obstructive pulmonary disease as any diagnosis among Medicare-eligible persons aged >= 65 years             11232
# Hospitalization for chronic obstructive pulmonary disease as first-listed diagnosis among Medicare-eligible persons aged >= 65 years    11232
# Hospitalization for hip fracture among Medicare-eligible persons aged >= 65 years                                                       11232
# Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years                                                      11232
# Mortality from coronary heart disease                                                                                                   11043
#                                                                                                                                         ...
# Health insurance coverage before pregnancy                                                                                                 55
# Prevalence of pre-pregnancy diabetes                                                                                                       55
# Postpartum depressive symptoms                                                                                                             55
# Pre-pregnancy hypertension                                                                                                                 55
# Prevalence of gestational diabetes                                                                                                         52
# Name: question, Length: 203, dtype: int64
# ---------- question ----------
#
# ---------- datavalueunit ---------
# %                        536781
# cases per 100,000         87526
# per 100,000               79872
# Number                    43995
# cases per 10,000          42880
# cases per 1,000           29952
# cases per 1,000,000        8208
# $                           648
# Years                       416
# pack sales per capita       275
# gallons                     220
# per 100,000 residents       165
# Name: datavalueunit, dtype: int64
# ---------- datavalueunit ----------
#
# ---------- datavaluetype ---------
# Crude Prevalence                                                    302039
# Age-adjusted Prevalence                                             232275
# Number                                                               85563
# Crude Rate                                                           83451
# Age-adjusted Rate                                                    83451
# Average Annual Crude Rate                                            39936
# Average Annual Number                                                39936
# Average Annual Age-adjusted Rate                                     39936
# Mean                                                                 19740
# Age-adjusted Mean                                                    19575
# Median                                                                4680
# Percent                                                               2415
# Yes/No                                                                1614
# Adjusted by age, sex, race and ethnicity                               832
# US Dollars                                                             648
# Per capita alcohol consumption                                         220
# Local control of the regulation of alcohol outlet density              165
# Commercial host (dram shop) liability status for alcohol service       110
# Prevalence                                                              52
# Name: datavaluetype, dtype: int64
# ---------- datavaluetype ----------
#
# ---------- datavalue ---------
# 4.0        1880
# 1.0        1607
# 3.0        1526
# 3.5        1406
# 5.0        1384
#            ...
# 73.85         1
# 34.66         1
# 1207.5        1
# 60314.0       1
# 41.87         1
# Name: datavalue, Length: 46247, dtype: int64
# ---------- datavalue ----------
#
# ---------- datavaluealt ---------
# 4.00        2073
# 1.00        1783
# 3.00        1633
# 5.00        1550
# 3.50        1505
#             ...
# 13875.00       1
# 362.04         1
# 242.59         1
# 195.48         1
# 16323.00       1
# Name: datavaluealt, Length: 37030, dtype: int64
# ---------- datavaluealt ----------
#
# ---------- datavaluefootnotesymbol ---------
# ****    144930
# -        76269
# ~        68093
# ~~~~     19926
# ���       4666
# ###       3996
# *         2703
# ~~        1153
# **         765
# &          679
# ##         211
# ^^         120
# ***        106
# �           18
# �,�          3
# ��           1
# ^^^          1
# Name: datavaluefootnotesymbol, dtype: int64
# ---------- datavaluefootnotesymbol ----------
#
# ---------- datavaluefootnote ---------
# Sample size of denominator and/or age group for age-standardization is less than 50 or relative standard error is more than 30%                                                                                                                                   144930
# No data available                                                                                                                                                                                                                                                  76269
# Data not shown because of too few respondents or cases                                                                                                                                                                                                             68093
# The state registry opted not to present state-specific estimates for this race/ethnicity group                                                                                                                                                                     19926
# Estimate is based on the first 3 quarters of 2015 and is not directly comparable to estimates in prior years due to changes in ICD codes                                                                                                                            4611
# Median frequency (50th percentile) reported with quartiles (25th & 75th percentiles)                                                                                                                                                                                3996
# 50 States + DC: US Median                                                                                                                                                                                                                                           2703
# Data cannot be calculated                                                                                                                                                                                                                                           1153
# US estimate/number is based on fewer than 50 states and the District of Columbia                                                                                                                                                                                     765
# Less than 60 respondents, interpret with caution                                                                                                                                                                                                                     679
# Estimate is 0.0% because no cases were reported with this condition                                                                                                                                                                                                  211
# State directly controlled the sale of (beer/wine/distilled spirits) at the retail and/or wholesale levels. State prices for (beer/wine/distilled spirits) combined both markups and taxes, so tax rates for this beverage type could not be determined.              120
# US Median is not available because the number of participating states is <30 (excludes states with sample size below 50 or relative standard error above 30%)                                                                                                        106
# A confidence interval for this location is not available because a census was used instead of a sample for their surveys                                                                                                                                              55
# Population served by CWS exceeded the US Census state population estimate; number of persons was reduced by the ratio of the population estimate to the CWS population estimate                                                                                       18
# Population served by CWS exceeded the US Census state population estimate; number of persons was reduced by the ratio of the population estimate to the CWS population estimate. Complete data were not available from WFRS; state provided other information.         3
# Per capita alcohol consumption was calculated using (1) alcohol beverage sales data, either collected directly from states or provided by beverage industry sources (numerator); and (2) population data from the U.S. Census Bureau (denominator).                    1
# DC was not rated for this measure because the measure addresses state versus local authority and does not apply to the District of Columbia                                                                                                                            1
# Name: datavaluefootnote, dtype: int64
# ---------- datavaluefootnote ----------
#
# ---------- lowconfidencelimit ---------
# 2.50      1767
# 2.40      1682
# 2.10      1678
# 2.60      1674
# 2.20      1657
#           ...
# 109.88       1
# 375.38       1
# 429.83       1
# 136.14       1
# 59.37        1
# Name: lowconfidencelimit, Length: 20500, dtype: int64
# ---------- lowconfidencelimit ----------
#
# ---------- highconfidencelimit ---------
# 2.00      1797
# 3.90      1324
# 4.00      1227
# 3.80      1227
# 4.20      1219
#           ...
# 223.99       1
# 436.53       1
# 360.69       1
# 226.79       1
# 103.91       1
# Name: highconfidencelimit, Length: 21919, dtype: int64
# ---------- highconfidencelimit ----------
#
# ---------- stratificationcategory1 ---------
# Race/Ethnicity    595152
# Gender            226352
# Overall           135134
# Name: stratificationcategory1, dtype: int64
# ---------- stratificationcategory1 ----------
#
# ---------- stratification1 ---------
# Overall                             135134
# Hispanic                            118672
# White, non-Hispanic                 118672
# Black, non-Hispanic                 118566
# Female                              113177
# Male                                113175
# Other, non-Hispanic                  69960
# Multiracial, non-Hispanic            69960
# American Indian or Alaska Native     49606
# Asian or Pacific Islander            47328
# Asian, non-Hispanic                   2388
# Name: stratification1, dtype: int64
# ---------- stratification1 ----------
#
# ---------- geolocation ---------
# POINT (-89.81637074 44.39319117)    18247
# POINT (-75.54397043 42.82700103)    18247
# POINT (-74.27369129 40.13057005)    18247
# POINT (-99.36572062 41.64104099)    18212
# POINT (-72.51764079 43.62538124)    18205
# POINT (-93.81649056 42.46940091)    18172
# POINT (-80.71264013 38.6655102)     18148
# POINT (-120.4700108 47.52227863)    18148
# POINT (-106.240581 34.52088095)     18148
# POINT (-157.8577494 21.30485044)    18120
# POINT (-84.71439027 44.66131954)    18113
# POINT (-106.1336109 38.84384076)    18108
# POINT (-84.77497105 37.64597027)    18072
# POINT (-72.08269067 42.27687047)    18043
# POINT (-92.27449074 34.74865012)    18043
# POINT (-111.5871306 39.36070017)    18043
# POINT (-79.15925046 35.46622098)    18037
# POINT (-76.60926011 39.29058096)    18008
# POINT (-71.52247031 41.70828019)    18008
# POINT (-120.1550313 44.56744942)    18008
# POINT (-81.04537121 33.9988213)     18002
# POINT (-81.92896054 28.93204038)    18002
# POINT (-117.0718406 39.49324039)    18002
# POINT (-111.7638113 34.86597028)    17997
# POINT (-100.3735306 44.35313005)    17973
# POINT (-92.56630005 38.63579078)    17854
# POINT (-77.86070029 40.79373015)    17854
# POINT (-147.722059 64.84507996)     17854
# POINT (-75.57774117 39.00883067)    17854
# POINT (-68.98503134 45.25422889)    17854
# POINT (-88.99771018 40.48501028)    17854
# POINT (-108.1098304 43.23554134)    17849
# POINT (-97.52107021 35.47203136)    17819
# POINT (-120.9999995 37.63864012)    17798
# POINT (-89.53803082 32.7455101)     17791
# POINT (-71.50036092 43.65595011)    17784
# POINT (-72.64984095 41.56266102)    17779
# POINT (-85.77449091 35.68094058)    17749
# POINT (-78.45789046 37.54268067)    17749
# POINT (-92.44568007 31.31266064)    17744
# POINT (-94.7942005 46.35564874)     17714
# POINT (-82.40426006 40.06021014)    17714
# POINT (-86.63186076 32.84057112)    17714
# POINT (-99.42677021 31.82724041)    17679
# POINT (-98.20078123 38.3477403)     17679
# POINT (-100.118421 47.47531978)     17679
# POINT (-83.62758035 32.83968109)    17677
# POINT (-109.4244206 47.06652897)    17644
# POINT (-114.36373 43.68263001)      17609
# POINT (-77.03196113 38.89037139)    17604
# POINT (-86.14996019 39.76691045)    17604
# POINT (-66.590149 18.220833)        11743
# POINT (-64.896335 18.335765)        11508
# POINT (144.793731 13.444304)        11459
# Name: geolocation, dtype: int64
# ---------- geolocation ----------
#
# ---------- locationid ---------
# 55    18247
# 34    18247
# 36    18247
# 31    18212
# 50    18205
# 19    18172
# 54    18148
# 53    18148
# 35    18148
# 15    18120
# 26    18113
# 8     18108
# 21    18072
# 5     18043
# 25    18043
# 49    18043
# 37    18037
# 44    18008
# 41    18008
# 24    18008
# 12    18002
# 45    18002
# 32    18002
# 4     17997
# 46    17973
# 23    17854
# 10    17854
# 29    17854
# 2     17854
# 17    17854
# 42    17854
# 56    17849
# 40    17819
# 6     17798
# 28    17791
# 33    17784
# 9     17779
# 51    17749
# 47    17749
# 22    17744
# 1     17714
# 27    17714
# 39    17714
# 20    17679
# 38    17679
# 48    17679
# 13    17677
# 30    17644
# 16    17609
# 18    17604
# 11    17604
# 72    11743
# 78    11508
# 66    11459
# 59     8072
# Name: locationid, dtype: int64
# ---------- locationid ----------
#
# ---------- topicid ---------
# CAN     133908
# CVD     128676
# DIA     128654
# COPD    127350
# AST      64719
# ART      62640
# NPAW     61397
# OVC      60365
# ALC      53220
# TOB      47669
# OLD      20784
# CKD      20537
# ORH      17564
# MTH      10810
# IMM       7830
# RPH       6858
# DIS       3657
# Name: topicid, dtype: int64
# ---------- topicid ----------
#
# ---------- questionid ---------
# CVD2_0     11232
# OLD1_0     11232
# COPD5_3    11232
# COPD5_4    11232
# DIA1_1     11043
#            ...
# CVD8_0        55
# MTH3_0        55
# DIA3_1        55
# OVC1_3        55
# DIA3_2        52
# Name: questionid, Length: 203, dtype: int64
# ---------- questionid ----------
#
# ---------- datavaluetypeid ---------
# CRDPREV              302039
# AGEADJPREV           232275
# NMBR                  85563
# CRDRATE               83451
# AGEADJRATE            83451
# AVGANNCRDRATE         39936
# AVGANNAGEADJRATE      39936
# AVGANNNMBR            39936
# MEAN                  19740
# AGEADJMEAN            19575
# MEDIAN                 4680
# PRCT                   2415
# YESNO                  1614
# AGESEXRACEADJRATE       832
# USD                     648
# PERCAPALC               220
# LCLCNTRLALC             165
# COMMHSTLIAB             110
# PREV                     52
# Name: datavaluetypeid, dtype: int64
# ---------- datavaluetypeid ----------
#
# ---------- stratificationcategoryid1 ---------
# RACE       595152
# GENDER     226352
# OVERALL    135134
# Name: stratificationcategoryid1, dtype: int64
# ---------- stratificationcategoryid1 ----------
#
# ---------- stratificationid1 ---------
# OVR     135134
# HIS     118672
# WHT     118672
# BLK     118566
# GENF    113177
# GENM    113175
# OTH      69960
# MRC      69960
# AIAN     34630
# API      32352
# APIO     14976
# AIAO     14976
# ASN       2388
# Name: stratificationid1, dtype: int64
# ---------- stratificationid1 ----------

# %%
df['locationabbr'].value_counts()
# Out:
# NY    18247
# WI    18247
# NJ    18247
# NE    18212
# VT    18205
# IA    18172
# WV    18148
# WA    18148
# NM    18148
# HI    18120
# MI    18113
# CO    18108
# KY    18072
# UT    18043
# MA    18043
# AR    18043
# NC    18037
# OR    18008
# MD    18008
# RI    18008
# NV    18002
# FL    18002
# SC    18002
# AZ    17997
# SD    17973
# MO    17854
# IL    17854
# DE    17854
# PA    17854
# AK    17854
# ME    17854
# WY    17849
# OK    17819
# CA    17798
# MS    17791
# NH    17784
# CT    17779
# TN    17749
# VA    17749
# LA    17744
# AL    17714
# MN    17714
# OH    17714
# TX    17679
# ND    17679
# KS    17679
# GA    17677
# MT    17644
# ID    17609
# IN    17604
# DC    17604
# PR    11743
# VI    11508
# GU    11459
# US     8072
# Name: locationabbr, dtype: int64

# %%
df['topic'].value_counts()
# Out:
# Cancer                                             133908
# Cardiovascular Disease                             128676
# Diabetes                                           128654
# Chronic Obstructive Pulmonary Disease              127350
# Asthma                                              64719
# Arthritis                                           62640
# Nutrition, Physical Activity, and Weight Status     61397
# Overarching Conditions                              60365
# Alcohol                                             53220
# Tobacco                                             47669
# Older Adults                                        20784
# Chronic Kidney Disease                              20537
# Oral Health                                         17564
# Mental Health                                       10810
# Immunization                                         7830
# Reproductive Health                                  6858
# Disability                                           3657
# Name: topic, dtype: int64

# %%
cancer = df[df['topic'].isin(['Cancer'])]
cancer['question'].value_counts()
# Out:
# Invasive cancer (all sites combined), mortality                                         7488
# Cancer of the female breast, mortality                                                  7488
# Cancer of the lung and bronchus, mortality                                              7488
# Invasive cancer of the female breast, incidence                                         7488
# Cancer of the colon and rectum (colorectal), incidence                                  7488
# Invasive cancer of the oral cavity or pharynx, incidence                                7488
# Cancer of the female cervix, mortality                                                  7488
# Cancer of the oral cavity and pharynx, mortality                                        7488
# Invasive cancer (all sites combined), incidence                                         7488
# Invasive cancer of the prostate, incidence                                              7488
# Invasive melanoma, incidence                                                            7488
# Cancer of the lung and bronchus, incidence                                              7488
# Invasive cancer of the cervix, incidence                                                7488
# Cancer of the prostate, mortality                                                       7488
# Cancer of the colon and rectum (colorectal), mortality                                  7488
# Melanoma, mortality                                                                     7488
# Fecal occult blood test, sigmoidoscopy, or colonoscopy among adults aged 50-75 years    4350
# Papanicolaou smear use among adult women aged 21-65 years                               3900
# Mammography use among women aged 50-74 years                                            3900
# Recent Papanicolaou smear use among women aged 21-44 years                              1950
# Name: question, dtype: int64

# %%
cardiovascular_disease = df[df['topic'].isin(['Cardiovascular Disease'])]
cardiovascular_disease['question'].value_counts()
# Out:
# Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years                                             11232
# Mortality from coronary heart disease                                                                                          11043
# Mortality from total cardiovascular diseases                                                                                   11043
# Mortality from diseases of the heart                                                                                           11043
# Mortality from cerebrovascular disease (stroke)                                                                                11043
# Mortality from heart failure                                                                                                    9816
# Influenza vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease or stroke     7830
# Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with a history of coronary heart disease            7830
# Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease            7830
# Influenza vaccination among noninstitutionalized adults aged >= 65 years with a history of coronary heart disease or stroke     7830
# Hospitalization for stroke                                                                                                      6528
# Hospitalization for acute myocardial infarction                                                                                 6528
# Taking medicine for high blood pressure control among adults aged >= 18 years with high blood pressure                          4350
# High cholesterol prevalence among adults aged >= 18 years                                                                       4350
# Awareness of high blood pressure among adults aged >= 18 years                                                                  4350
# Cholesterol screening among adults aged >= 18 years                                                                             4350
# Awareness of high blood pressure among women aged 18-44 years                                                                   1625
# Pre-pregnancy hypertension                                                                                                        55
# Name: question, dtype: int64

# %%
diabetes = df[df['topic'].isin(['Diabetes'])]
diabetes['question'].value_counts()
# Out:
# Mortality with diabetic ketoacidosis reported as any listed cause of death                             11043
# Mortality due to diabetes reported as any listed cause of death                                        11043
# Adults with diagnosed diabetes aged >= 18 years who have taken a diabetes self-management course        7830
# Dilated eye examination among adults aged >= 18 years with diagnosed diabetes                           7830
# Glycosylated hemoglobin measurement among adults aged >= 18 years with diagnosed diabetes               7830
# Influenza vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes        7830
# Prevalence of depressive disorders among adults aged >= 18 years with diagnosed diabetes                7830
# Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with diagnosed diabetes     7830
# Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes     7830
# Foot examination among adults aged >= 18 years with diagnosed diabetes                                  7830
# Influenza vaccination among noninstitutionalized adults aged 18-64 years with diagnosed diabetes        7830
# Prevalence of diagnosed diabetes among adults aged >= 18 years                                          7830
# Amputation of a lower extremity attributable to diabetes                                                6528
# Hospitalization with diabetes as a listed diagnosis                                                     6528
# Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes                 4350
# Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes                    4350
# Visits to dentist or dental clinic among adults aged >= 18 years with diagnosed diabetes                3480
# Diabetes prevalence among women aged 18-44 years                                                        2925
# Prevalence of pre-pregnancy diabetes                                                                      55
# Prevalence of gestational diabetes                                                                        52
# Name: question, dtype: int64

# %%
#select location not null
df_location = df[(df['geolocation'].notnull())]
df_location.shape
# Out:
# (948566, 24)

# %%
df_location.describe().T
# Out:
#                         count         mean          std      min      25%  \
# yearstart            948566.0  2014.177932     2.826398  2001.00  2012.00
# yearend              948566.0  2014.674914     2.465141  2001.00  2013.00
# datavaluealt         636481.0   717.540429  6880.413470     0.00    17.50
# lowconfidencelimit   542542.0    51.418692    88.827386     0.00    12.00
# highconfidencelimit  542542.0    63.513183    99.773431     0.08    17.88
# locationid           948566.0    30.575837    17.405737     1.00    17.00
#
#                         50%     75%       max
# yearstart            2014.0  2017.0    2020.0
# yearend              2015.0  2017.0    2020.0
# datavaluealt           41.0    76.2  701437.0
# lowconfidencelimit     29.5    56.9    1615.7
# highconfidencelimit    42.5    71.7    2137.0
# locationid             30.0    44.0      78.0

# %%
df['geolocation'].head(3)
# Out:
# 0     POINT (-147.722059 64.84507996)
# 1     POINT (-147.722059 64.84507996)
# 2    POINT (-111.7638113 34.86597028)
# Name: geolocation, dtype: object

# %%
df.locationabbr.describe
# Out:
# <bound method NDFrame.describe of 0         AK
# 1         AK
# 2         AZ
# 3         NY
# 4         NY
#           ..
# 956633    NH
# 956634    SD
# 956635    WI
# 956636    MI
# 956637    OH
# Name: locationabbr, Length: 956638, dtype: object>

# %%
# 17 types of diseases
set(df.topic)
# Out:
# {'Alcohol',
#  'Arthritis',
#  'Asthma',
#  'Cancer',
#  'Cardiovascular Disease',
#  'Chronic Kidney Disease',
#  'Chronic Obstructive Pulmonary Disease',
#  'Diabetes',
#  'Disability',
#  'Immunization',
#  'Mental Health',
#  'Nutrition, Physical Activity, and Weight Status',
#  'Older Adults',
#  'Oral Health',
#  'Overarching Conditions',
#  'Reproductive Health',
#  'Tobacco'}

# %%
df.topic.unique()
# Out:
# array(['Cancer', 'Alcohol', 'Asthma', 'Chronic Kidney Disease',
#        'Cardiovascular Disease', 'Overarching Conditions', 'Diabetes',
#        'Tobacco', 'Arthritis', 'Mental Health',
#        'Nutrition, Physical Activity, and Weight Status', 'Oral Health',
#        'Older Adults', 'Disability',
#        'Chronic Obstructive Pulmonary Disease', 'Reproductive Health',
#        'Immunization'], dtype=object)

# %%
# 33 data sources
set(df.datasource)
# Out:
# {'ACS 1-Year Estimates',
#  'ACS 5-Year Estimates',
#  'AEDS',
#  'ANRF',
#  'APIS',
#  'ASHW',
#  'BRFSS',
#  'Birth Certificate, NVSS',
#  'CDC Breastfeeding Report Card',
#  "CDC Children's Food Environment State Indicator Report",
#  'CDC School Health Profiles',
#  'CMS CCW',
#  'CMS Part A Claims Data',
#  'Current Population Survey',
#  'Death Certificate',
#  'HRSA, UDS',
#  'InfoUSA; USDA',
#  'Legal Research',
#  'NSCH',
#  'NVSS',
#  'NVSS, Mortality',
#  'National Immunization Survey',
#  'PRAMS',
#  'SEDD; SID',
#  'STATE',
#  'State Inpatient Data',
#  'Statewide central cancer registries',
#  "USDA National Farmers' Market Directory",
#  'USRDS',
#  'WFRS',
#  'YRBSS',
#  'mPINC'}

# %%
# 202 unique questions
set(df.question)
# all questions
#df.question.unique()
# Out:
# {'Activity limitation due to arthritis among adults aged >= 18 years who have doctor-diagnosed arthritis',
#  'Adults aged >= 18 years with arthritis who have taken a class to learn how to manage arthritis symptoms',
#  'Adults with diagnosed diabetes aged >= 18 years who have taken a diabetes self-management course',
#  'Alcohol use among youth',
#  'Alcohol use before pregnancy',
#  'All teeth lost among adults aged >= 65 years',
#  'Amount of alcohol excise tax by beverage type (beer)',
#  'Amount of alcohol excise tax by beverage type (distilled spirits)',
#  'Amount of alcohol excise tax by beverage type (wine)',
#  'Amount of tobacco product excise tax',
#  'Amputation of a lower extremity attributable to diabetes',
#  'Arthritis among adults aged >= 18 years',
#  'Arthritis among adults aged >= 18 years who are obese',
#  'Arthritis among adults aged >= 18 years who have diabetes',
#  'Arthritis among adults aged >= 18 years who have heart disease',
#  'Asthma mortality rate',
#  'Asthma prevalence among women aged 18-44 years',
#  'At least 14 recent mentally unhealthy days among women aged 18-44 years',
#  'Awareness of high blood pressure among adults aged >= 18 years',
#  'Awareness of high blood pressure among women aged 18-44 years',
#  'Binge drinking frequency among adults aged >= 18 years who binge drink',
#  'Binge drinking intensity among adults aged >= 18 years who binge drink',
#  'Binge drinking prevalence among adults aged >= 18 years',
#  'Binge drinking prevalence among women aged 18-44 years',
#  'Binge drinking prevalence among youth',
#  'Cancer of the colon and rectum (colorectal), incidence',
#  'Cancer of the colon and rectum (colorectal), mortality',
#  'Cancer of the female breast, mortality',
#  'Cancer of the female cervix, mortality',
#  'Cancer of the lung and bronchus, incidence',
#  'Cancer of the lung and bronchus, mortality',
#  'Cancer of the oral cavity and pharynx, mortality',
#  'Cancer of the prostate, mortality',
#  'Census tracts with healthier food retailers within � mile of boundary',
#  'Cholesterol screening among adults aged >= 18 years',
#  'Chronic liver disease mortality',
#  'Cigarette smoking before pregnancy',
#  'Commercial host (dram shop) liability laws',
#  'Computer use among high school students',
#  'Current asthma prevalence among adults aged >= 18 years',
#  'Current cigarette smoking among women aged 18-44 years',
#  'Current cigarette smoking among youth',
#  'Current health care coverage among women aged 18-44 years',
#  'Current lack of health insurance among adults aged 18-64 years',
#  'Current smokeless tobacco use among adults aged >= 18 years',
#  'Current smokeless tobacco use among youth',
#  'Current smoking among adults aged >= 18 years',
#  'Dental visits among children and adolescents aged 1-17 years',
#  'Diabetes prevalence among women aged 18-44 years',
#  'Dilated eye examination among adults aged >= 18 years with diagnosed diabetes',
#  'Disability among adults aged >= 65 years',
#  'Emergency department visit rate for asthma',
#  'Emergency department visit rate for chronic obstructive pulmonary disease as any diagnosis',
#  'Emergency department visit rate for chronic obstructive pulmonary disease as first-listed diagnosis',
#  'Fair or poor health among adults aged >= 18 years with arthritis',
#  'Fair or poor self-rated health status among adults aged >= 18 years',
#  'Farmers markets that accept Supplemental Nutrition Assistance Program (SNAP) benefits',
#  'Farmers markets that accept Women and Infant Children (WIC) farmers market nutrition program coupons',
#  'Fecal occult blood test, sigmoidoscopy, or colonoscopy among adults aged 50-75 years',
#  'Folic acid supplementation',
#  'Foot examination among adults aged >= 18 years with diagnosed diabetes',
#  'Gini Index of income inequality',
#  'Glycosylated hemoglobin measurement among adults aged >= 18 years with diagnosed diabetes',
#  'Health insurance coverage before pregnancy',
#  'Healthy weight among adults aged >= 18 years',
#  'Healthy weight among high school students',
#  'Heavy drinking among adults aged >= 18 years',
#  'Heavy drinking among women aged 18-44 years',
#  'High cholesterol prevalence among adults aged >= 18 years',
#  'High school completion among adults aged 18-24 years',
#  'High school completion among women aged 18-44 years',
#  'Hospitalization for acute myocardial infarction',
#  'Hospitalization for chronic obstructive pulmonary disease as any diagnosis',
#  'Hospitalization for chronic obstructive pulmonary disease as any diagnosis among Medicare-eligible persons aged >= 65 years',
#  'Hospitalization for chronic obstructive pulmonary disease as first-listed diagnosis',
#  'Hospitalization for chronic obstructive pulmonary disease as first-listed diagnosis among Medicare-eligible persons aged >= 65 years',
#  'Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years',
#  'Hospitalization for hip fracture among Medicare-eligible persons aged >= 65 years',
#  'Hospitalization for stroke',
#  'Hospitalization with diabetes as a listed diagnosis',
#  'Hospitalizations for asthma',
#  'Incidence of treated end-stage renal disease',
#  'Incidence of treated end-stage renal disease attributed to diabetes',
#  'Infants breastfed at 6 months',
#  'Influenza vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease or stroke',
#  'Influenza vaccination among noninstitutionalized adults aged 18-64 years with asthma',
#  'Influenza vaccination among noninstitutionalized adults aged 18-64 years with diagnosed diabetes',
#  'Influenza vaccination among noninstitutionalized adults aged >= 18 years',
#  'Influenza vaccination among noninstitutionalized adults aged >= 45 years with chronic obstructive pulmonary disease',
#  'Influenza vaccination among noninstitutionalized adults aged >= 65 years with a history of coronary heart disease or stroke',
#  'Influenza vaccination among noninstitutionalized adults aged >= 65 years with asthma',
#  'Influenza vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes',
#  'Invasive cancer (all sites combined), incidence',
#  'Invasive cancer (all sites combined), mortality',
#  'Invasive cancer of the cervix, incidence',
#  'Invasive cancer of the female breast, incidence',
#  'Invasive cancer of the oral cavity or pharynx, incidence',
#  'Invasive cancer of the prostate, incidence',
#  'Invasive melanoma, incidence',
#  'Life expectancy at age 65 years',
#  'Life expectancy at birth',
#  'Live births occurring at Baby Friendly Facilities',
#  'Local authority to regulate alcohol outlet density',
#  'Mammography use among women aged 50-74 years',
#  'Mean maternity practices in infant nutrition care (mPINC) score',
#  'Median daily frequency of fruit consumption among adults aged >= 18 years',
#  'Median daily frequency of fruit consumption among high school students',
#  'Median daily frequency of vegetable consumption among adults aged >= 18 years',
#  'Median daily frequency of vegetable consumption among high school students',
#  'Meeting aerobic physical activity guidelines among high school students',
#  'Meeting aerobic physical activity guidelines for additional and more extensive health benefits among adults aged >= 18 years',
#  'Meeting aerobic physical activity guidelines for substantial health benefits among adults aged >= 18 years',
#  'Meeting aerobic physical activity guidelines for substantial health benefits and for muscle-strengthening activity among adults aged >= 18 years',
#  'Melanoma, mortality',
#  'Mortality due to diabetes reported as any listed cause of death',
#  'Mortality from cerebrovascular disease (stroke)',
#  'Mortality from coronary heart disease',
#  'Mortality from diseases of the heart',
#  'Mortality from heart failure',
#  'Mortality from total cardiovascular diseases',
#  'Mortality with chronic obstructive pulmonary disease as underlying cause among adults aged >= 45 years',
#  'Mortality with chronic obstructive pulmonary disease as underlying or contributing cause among adults aged >= 45 years',
#  'Mortality with diabetic ketoacidosis reported as any listed cause of death',
#  'Mortality with end-stage renal disease',
#  'No leisure-time physical activity among adults aged >= 18 years',
#  'No tooth loss among adults aged 18-64 years',
#  'Number of farmers markets per 100,000 residents',
#  'Obesity among adults aged >= 18 years',
#  'Obesity among high school students',
#  'Oral health services at Federally Qualified Health Centers',
#  'Overweight or obesity among adults aged >= 18 years',
#  'Overweight or obesity among high school students',
#  'Overweight or obesity among women aged 18-44 years',
#  'Papanicolaou smear use among adult women aged 21-65 years',
#  'Participation in daily school physical education classes among high school students',
#  'Per capita alcohol consumption among persons aged >= 14 years',
#  'Percent tobacco revenue to fund at CDC recommended level',
#  'Physical inactivity among adults aged >= 18 years with arthritis',
#  'Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years who smoke',
#  'Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease',
#  'Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with asthma',
#  'Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with diagnosed diabetes',
#  'Pneumococcal vaccination among noninstitutionalized adults aged >= 45 years with chronic obstructive pulmonary disease',
#  'Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years who smoke',
#  'Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with a history of coronary heart disease',
#  'Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with asthma',
#  'Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes',
#  'Population served by community water systems that receive fluoridated drinking water',
#  'Postpartum checkup',
#  'Postpartum depressive symptoms',
#  'Poverty',
#  'Poverty among women aged 18-44 years',
#  'Pre-pregnancy hypertension',
#  'Premature mortality among adults aged 45-64 years',
#  'Presence of regulations pertaining to avoiding sugar in early care and education settings',
#  'Presence of regulations pertaining to screen time in early care and education settings',
#  'Presence of regulations pertaining to serving fruit in early care and education settings',
#  'Presence of regulations pertaining to serving vegetables in early care and education settings',
#  'Prevalence of 2 or more chronic conditions among Medicare-enrolled persons aged >= 65 years',
#  'Prevalence of activity limitation among adults >= 18 with diagnosed chronic obstructive pulmonary disease',
#  'Prevalence of activity limitation among adults >= 45 years with diagnosed chronic obstructive pulmonary disease',
#  'Prevalence of chronic kidney disease among adults aged >= 18 years',
#  'Prevalence of chronic obstructive pulmonary disease among adults >= 18',
#  'Prevalence of chronic obstructive pulmonary disease among adults >= 45 years',
#  'Prevalence of current smoking among adults >= 18 with diagnosed chronic obstructive pulmonary disease',
#  'Prevalence of current smoking among adults >= 45 years with diagnosed chronic obstructive pulmonary disease',
#  'Prevalence of depressive disorders among adults aged >= 18 years with diagnosed diabetes',
#  'Prevalence of diagnosed diabetes among adults aged >= 18 years',
#  'Prevalence of gestational diabetes',
#  'Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes',
#  'Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes',
#  'Prevalence of pre-pregnancy diabetes',
#  'Prevalence of sufficient sleep among adults aged >= 18 years',
#  'Preventive dental care before pregnancy',
#  'Preventive dental visits among children and adolescents aged 1-17 years',
#  'Proportion of older adults aged 50-64 years who are up to date on a core set of clinical preventive services',
#  'Proportion of older adults aged >= 65 years who are up to date on a core set of clinical preventive services',
#  'Proportion of the population protected by a comprehensive smoke-free policy prohibiting smoking in all indoor areas of workplaces and public places, including restaurants and bars',
#  'Quit attempts in the past year among current smokers',
#  'Receiving formula supplementation within the first 2 days of life among breastfed infants',
#  'Recent Papanicolaou smear use among women aged 21-44 years',
#  'Recent activity limitation among adults aged >= 18 years',
#  'Recent mentally unhealthy days among adults aged >= 18 years',
#  'Recent physically unhealthy days among adults aged >= 18 years',
#  'Sale of cigarette packs',
#  'Secondary schools that allow community-sponsored use of physical activity facilities by youth outside of normal school hours',
#  'Secondary schools that allow students to purchase soda or fruit drinks',
#  'Secondary schools that allow students to purchase sports drinks',
#  'Secondary schools that have a comprehensive tobacco-free school policy in place',
#  'Secondary schools that offer less healthy foods as competitive foods',
#  'Self-rated health status among women aged 18-44 years',
#  'Severe joint pain due to arthritis among adults aged >= 18 years who have doctor-diagnosed arthritis',
#  'Six or more teeth lost among adults aged >= 65 years',
#  'Soda consumption among high school students',
#  'State child care regulation supports onsite breastfeeding',
#  'States that allow stronger local tobacco control and prevention laws',
#  'States with strong polices that require retail licenses to sell tobacco products',
#  'Taking medicine for high blood pressure control among adults aged >= 18 years with high blood pressure',
#  'Television viewing among high school students',
#  'Timeliness of routine health care checkup among women aged 18-44 years',
#  'Visits to dentist or dental clinic among adults aged >= 18 years',
#  'Visits to dentist or dental clinic among adults aged >= 18 years with diagnosed diabetes',
#  'Work limitation due to arthritis among adults aged 18-64 years who have doctor-diagnosed arthritis'}

# %%
set(df.datavalueunit)
# Out:
# {'$',
#  '%',
#  'Number',
#  'Years',
#  'cases per 1,000',
#  'cases per 1,000,000',
#  'cases per 10,000',
#  'cases per 100,000',
#  'gallons',
#  nan,
#  'pack sales per capita',
#  'per 100,000',
#  'per 100,000 residents'}

# %%
set(df.datavaluetype)
# Out:
# {'Adjusted by age, sex, race and ethnicity',
#  'Age-adjusted Mean',
#  'Age-adjusted Prevalence',
#  'Age-adjusted Rate',
#  'Average Annual Age-adjusted Rate',
#  'Average Annual Crude Rate',
#  'Average Annual Number',
#  'Commercial host (dram shop) liability status for alcohol service',
#  'Crude Prevalence',
#  'Crude Rate',
#  'Local control of the regulation of alcohol outlet density',
#  'Mean',
#  'Median',
#  'Number',
#  'Per capita alcohol consumption',
#  'Percent',
#  'Prevalence',
#  'US Dollars',
#  'Yes/No'}

# %%
# something interesting here datavalue and datavalue alt are in object adn float64 format
df.datavalue.head()
# Out:
# 0      3
# 1     15
# 2    109
# 3    329
# 4    336
# Name: datavalue, dtype: object

# %%
df.datavaluealt.head()
# Out:
# 0      3.0
# 1     15.0
# 2    109.0
# 3    329.0
# 4    336.0
# Name: datavaluealt, dtype: float64

# %%
set(df.stratificationcategory1) #interesting insight into stratificationcategory1 and stratification1 which is an explanation of the main categories
# Out:
# {'Gender', 'Overall', 'Race/Ethnicity'}

# %%
set(df.stratification1)
# Out:
# {'American Indian or Alaska Native',
#  'Asian or Pacific Islander',
#  'Asian, non-Hispanic',
#  'Black, non-Hispanic',
#  'Female',
#  'Hispanic',
#  'Male',
#  'Multiracial, non-Hispanic',
#  'Other, non-Hispanic',
#  'Overall',
#  'White, non-Hispanic'}

# %%
set(df.stratificationcategoryid1)  #same as the 2 categories above but with labels
# Out:
# {'GENDER', 'OVERALL', 'RACE'}

# %%
set(df.stratificationid1)
# Out:
# {'AIAN',
#  'AIAO',
#  'API',
#  'APIO',
#  'ASN',
#  'BLK',
#  'GENF',
#  'GENM',
#  'HIS',
#  'MRC',
#  'OTH',
#  'OVR',
#  'WHT'}

# %%
#let's plot a heatmap to see the missing data visually

# %%
plt.figure(figsize=(16, 6))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='coolwarm')
# https://indianaiproduction.com/seaborn-heatmap/
# Out:
# <AxesSubplot:>

# %%
df['datavaluefootnotesymbol'].count()
df_datavalfoot = []
for i in df['datavaluefootnotesymbol']:
    if (pd.isnull(i) is False):
        if i is not ' ':
            df_datavalfoot.append(i)

# %%
len(df_datavalfoot)
#to show how much data is in this column, excluding nulls or blank (' ') spaces
# Out:
# 323640

# %%
# there are some columns which we don't need at the moment
df_new = df.drop(columns = ['yearend','locationdesc','datasource','datavalue','datavaluefootnotesymbol','datavaluefootnote','lowconfidencelimit','highconfidencelimit'])
#df_new

# %%
#let's look at the questions to try to understand what the data shows up
#drop locationid and yearstart since I don't need those now

#df_question = df_new.pivot_table(index = ['topic','questionid','question','datavalueunit','datavaluetype'],columns = None, dropna = True)
#df_question.drop(columns = ['locationid','yearstart']).round(2).head(30) 
df_question = df_new.groupby(['topic','questionid','question','datavalueunit','datavaluetype']).mean().round(2)
df_question = df_question.drop(columns = ['locationid','yearstart'])
df_question.head(35)
# Out:
#                                                                                                                           datavaluealt
# topic     questionid question                                           datavalueunit     datavaluetype
# Alcohol   ALC1_1     Alcohol use among youth                            %                 Crude Prevalence                       28.31
#           ALC1_2     Alcohol use before pregnancy                       %                 Crude Prevalence                       50.44
#           ALC2_1     Binge drinking prevalence among youth              %                 Crude Prevalence                       13.31
#           ALC2_2     Binge drinking prevalence among adults aged >= ... %                 Age-adjusted Prevalence                17.31
#                                                                                           Crude Prevalence                       17.30
#           ALC2_3     Binge drinking prevalence among women aged 18-4... %                 Crude Prevalence                       17.88
#           ALC3_0     Binge drinking frequency among adults aged >= 1... Number            Age-adjusted Mean                       4.45
#                                                                                           Mean                                    4.29
#           ALC4_0     Binge drinking intensity among adults aged >= 1... Number            Age-adjusted Mean                       7.06
#                                                                                           Mean                                    7.40
#           ALC5_1     Heavy drinking among adults aged >= 18 years       %                 Age-adjusted Prevalence                 6.33
#                                                                                           Crude Prevalence                        6.22
#           ALC5_2     Heavy drinking among women aged 18-44 years        %                 Crude Prevalence                        6.70
#           ALC6_0     Chronic liver disease mortality                    cases per 100,000 Age-adjusted Rate                      12.29
#                                                                                           Crude Rate                             12.97
#           ALC7_0     Per capita alcohol consumption among persons ag... gallons           Per capita alcohol consumption          2.48
#           ALC8_0_1   Amount of alcohol excise tax by beverage type (... $                 US Dollars                              0.31
#           ALC8_0_2   Amount of alcohol excise tax by beverage type (... $                 US Dollars                              0.80
#           ALC8_0_3   Amount of alcohol excise tax by beverage type (... $                 US Dollars                              4.41
# Arthritis ART1_1     Arthritis among adults aged >= 18 years            %                 Age-adjusted Prevalence                24.52
#                                                                                           Crude Prevalence                       24.19
#           ART1_2     Arthritis among adults aged >= 18 years who are... %                 Age-adjusted Prevalence                30.81
#                                                                                           Crude Prevalence                       33.65
#           ART1_3     Arthritis among adults aged >= 18 years who hav... %                 Age-adjusted Prevalence                36.33
#                                                                                           Crude Prevalence                       48.56
#           ART1_4     Arthritis among adults aged >= 18 years who hav... %                 Age-adjusted Prevalence                44.66
#                                                                                           Crude Prevalence                       56.14
#           ART2_1     Activity limitation due to arthritis among adul... %                 Age-adjusted Prevalence                51.03
#                                                                                           Crude Prevalence                       51.40
#           ART2_2     Severe joint pain due to arthritis among adults... %                 Age-adjusted Prevalence                33.82
#                                                                                           Crude Prevalence                       33.44
#           ART2_3     Work limitation due to arthritis among adults a... %                 Age-adjusted Prevalence                44.79
#                                                                                           Crude Prevalence                       44.19
#           ART3_0     Physical inactivity among adults aged >= 18 yea... %                 Age-adjusted Prevalence                31.20
#                                                                                           Crude Prevalence                       34.63

# %%
#we summarized the data using questions, but what about the states
df_states = df_new.pivot_table(values = 'datavaluealt', index = ['topic','questionid','question','datavalueunit','datavaluetype'],columns = 'locationabbr',aggfunc = 'mean',dropna=True).round(2)
df_states
# Out:
# locationabbr                                                                                                    AK  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         23.25
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         53.70
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         13.76
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         19.57
#                                                                                     Age-adjusted Prevalence  18.68
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         60.98
#                                                                                     Age-adjusted Prevalence  59.40
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  44.97
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  11.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  47.75
#
# locationabbr                                                                                                    AL  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         32.38
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         45.24
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         17.75
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         12.99
#                                                                                     Age-adjusted Prevalence  13.82
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         65.19
#                                                                                     Age-adjusted Prevalence  64.68
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  12.47
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  23.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  68.70
#
# locationabbr                                                                                                    AR  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         29.69
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         45.04
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         12.76
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         14.64
#                                                                                     Age-adjusted Prevalence  15.06
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         62.47
#                                                                                     Age-adjusted Prevalence  61.92
#         TOB6_0     Proportion of the population protected by a com... %             Percent                   0.37
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  15.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  64.58
#
# locationabbr                                                                                                     AZ  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          34.85
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence            NaN
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          18.93
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          15.63
#                                                                                     Age-adjusted Prevalence   15.60
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          61.08
#                                                                                     Age-adjusted Prevalence   60.01
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   16.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   59.07
#
# locationabbr                                                                                                    CA  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         28.33
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence           NaN
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         12.12
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         16.34
#                                                                                     Age-adjusted Prevalence  16.53
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         62.20
#                                                                                     Age-adjusted Prevalence  61.53
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  46.70
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  22.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  65.72
#
# locationabbr                                                                                                     CO  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          26.56
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          54.44
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          14.72
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          17.78
#                                                                                     Age-adjusted Prevalence   17.28
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          64.16
#                                                                                     Age-adjusted Prevalence   63.01
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   18.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   56.10
#
# locationabbr                                                                                                    CT  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         30.22
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         50.36
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         13.52
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         16.36
#                                                                                     Age-adjusted Prevalence  16.71
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         66.71
#                                                                                     Age-adjusted Prevalence  66.51
#         TOB6_0     Proportion of the population protected by a com... %             Percent                   0.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   9.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  57.45
#
# locationabbr                                                                                                     DC  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          25.12
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence            NaN
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence           9.28
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          24.99
#                                                                                     Age-adjusted Prevalence   22.37
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          67.24
#                                                                                     Age-adjusted Prevalence   66.87
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   16.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   40.60
#
# locationabbr                                                                                                     DE  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          31.18
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          45.47
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          15.76
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          16.97
#                                                                                     Age-adjusted Prevalence   17.13
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          62.49
#                                                                                     Age-adjusted Prevalence   62.05
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   11.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   55.60
#
# locationabbr                                                                                                    FL  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         29.45
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence           NaN
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         12.78
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         15.34
#                                                                                     Age-adjusted Prevalence  16.14
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         66.00
#                                                                                     Age-adjusted Prevalence  65.91
#         TOB6_0     Proportion of the population protected by a com... %             Percent                   0.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  18.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  60.08
#
# locationabbr                                                                                                    GA  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         28.08
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         38.74
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         13.30
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         14.77
#                                                                                     Age-adjusted Prevalence  14.42
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         65.37
#                                                                                     Age-adjusted Prevalence  64.73
#         TOB6_0     Proportion of the population protected by a com... %             Percent                   3.13
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  29.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  66.25
#
# locationabbr                                                                                                    GU  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         20.66
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence           NaN
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          8.80
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         21.46
#                                                                                     Age-adjusted Prevalence  20.30
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         69.47
#                                                                                     Age-adjusted Prevalence  68.36
#         TOB6_0     Proportion of the population protected by a com... %             Percent                   0.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                    NaN
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  58.30
#
# locationabbr                                                                                                     HI  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          25.81
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          55.01
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          12.60
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          20.34
#                                                                                     Age-adjusted Prevalence   20.82
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          61.75
#                                                                                     Age-adjusted Prevalence   60.83
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                    9.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   64.55
#
# locationabbr                                                                                                     IA  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          24.85
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          51.65
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          10.98
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          20.90
#                                                                                     Age-adjusted Prevalence   20.96
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          56.40
#                                                                                     Age-adjusted Prevalence   55.84
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   17.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   56.45
#
# locationabbr                                                                                                    ID  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         28.15
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence           NaN
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         15.83
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         15.98
#                                                                                     Age-adjusted Prevalence  16.03
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         57.73
#                                                                                     Age-adjusted Prevalence  57.11
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  13.47
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  22.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  49.95
#
# locationabbr                                                                                                     IL  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          28.97
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          50.89
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          11.78
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          20.18
#                                                                                     Age-adjusted Prevalence   20.10
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          64.03
#                                                                                     Age-adjusted Prevalence   64.48
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   16.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   55.27
#
# locationabbr                                                                                                    IN  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         29.95
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence           NaN
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         17.40
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         16.61
#                                                                                     Age-adjusted Prevalence  16.38
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         60.57
#                                                                                     Age-adjusted Prevalence  60.31
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  29.07
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  15.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  55.63
#
# locationabbr                                                                                                     KS  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          28.32
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          54.65
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          15.20
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          16.11
#                                                                                     Age-adjusted Prevalence   15.88
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          61.11
#                                                                                     Age-adjusted Prevalence   59.80
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   18.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   49.18
#
# locationabbr                                                                                                    KY  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         27.58
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         51.09
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         13.34
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         16.09
#                                                                                     Age-adjusted Prevalence  16.59
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         59.13
#                                                                                     Age-adjusted Prevalence  58.42
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  33.23
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  18.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  37.90
#
# locationabbr                                                                                                    LA  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         36.00
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         47.92
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         14.33
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         17.94
#                                                                                     Age-adjusted Prevalence  17.58
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         63.39
#                                                                                     Age-adjusted Prevalence  63.05
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  13.37
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  20.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  56.00
#
# locationabbr                                                                                                     MA  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          30.24
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          54.86
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          14.37
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          17.50
#                                                                                     Age-adjusted Prevalence   17.34
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          63.88
#                                                                                     Age-adjusted Prevalence   64.11
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   10.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   60.00
#
# locationabbr                                                                                                     MD  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          26.36
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          43.51
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          12.86
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          14.92
#                                                                                     Age-adjusted Prevalence   14.90
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          63.18
#                                                                                     Age-adjusted Prevalence   62.50
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   12.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   63.62
#
# locationabbr                                                                                                     ME  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          23.14
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          68.05
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          13.05
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          18.52
#                                                                                     Age-adjusted Prevalence   19.80
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          59.37
#                                                                                     Age-adjusted Prevalence   59.22
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                    8.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   64.52
#
# locationabbr                                                                                                     MI  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          25.71
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          53.82
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          13.20
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          18.70
#                                                                                     Age-adjusted Prevalence   18.59
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          64.30
#                                                                                     Age-adjusted Prevalence   64.03
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                    9.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   58.72
#
# locationabbr                                                                                                     MN  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence            NaN
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          53.12
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence            NaN
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          19.58
#                                                                                     Age-adjusted Prevalence   19.11
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          62.54
#                                                                                     Age-adjusted Prevalence   61.65
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   10.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   61.35
#
# locationabbr                                                                                                    MO  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         33.35
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         55.18
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         16.10
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         18.40
#                                                                                     Age-adjusted Prevalence  18.50
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         58.72
#                                                                                     Age-adjusted Prevalence  59.01
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  23.60
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  30.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  46.55
#
# locationabbr                                                                                                    MS  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         31.04
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         49.00
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         16.00
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         14.02
#                                                                                     Age-adjusted Prevalence  14.85
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         64.73
#                                                                                     Age-adjusted Prevalence  64.43
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  24.53
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  19.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  71.32
#
# locationabbr                                                                                                     MT  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          35.11
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          69.80
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          18.90
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          21.81
#                                                                                     Age-adjusted Prevalence   21.73
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          58.15
#                                                                                     Age-adjusted Prevalence   57.20
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   12.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   62.42
#
# locationabbr                                                                                                    NC  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         26.96
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         44.40
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         11.70
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         14.21
#                                                                                     Age-adjusted Prevalence  14.22
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         64.22
#                                                                                     Age-adjusted Prevalence  64.05
#         TOB6_0     Proportion of the population protected by a com... %             Percent                   0.10
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  29.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  76.62
#
# locationabbr                                                                                                     ND  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          32.37
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          60.09
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          17.83
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          24.75
#                                                                                     Age-adjusted Prevalence   23.71
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          57.26
#                                                                                     Age-adjusted Prevalence   56.04
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   18.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   55.58
#
# locationabbr                                                                                                     NE  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          23.67
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          49.90
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          11.83
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          19.58
#                                                                                     Age-adjusted Prevalence   19.25
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          61.24
#                                                                                     Age-adjusted Prevalence   59.68
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   19.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   43.65
#
# locationabbr                                                                                                    NH  \
# ...
#                                                                                     Age-adjusted Prevalence  62.16
#         TOB6_0     Proportion of the population protected by a com... %             Percent                   0.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  22.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  49.30
#
# locationabbr                                                                                                    TX  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         30.58
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         46.93
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         12.90
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         16.78
#                                                                                     Age-adjusted Prevalence  16.43
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         64.55
#                                                                                     Age-adjusted Prevalence  64.17
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  38.80
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  19.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  73.73
#
# locationabbr                                                                                                    US  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         30.50
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         47.03
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         13.88
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         16.93
#                                                                                     Age-adjusted Prevalence  17.74
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         60.73
#                                                                                     Age-adjusted Prevalence  60.29
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  49.35
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                    NaN
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                    NaN
#
# locationabbr                                                                                                     UT  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          12.14
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          27.23
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence           5.65
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          12.59
#                                                                                     Age-adjusted Prevalence   11.78
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          64.50
#                                                                                     Age-adjusted Prevalence   63.05
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   18.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   59.90
#
# locationabbr                                                                                                    VA  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         22.49
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         46.24
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         11.43
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         15.43
#                                                                                     Age-adjusted Prevalence  15.21
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         63.57
#                                                                                     Age-adjusted Prevalence  62.99
#         TOB6_0     Proportion of the population protected by a com... %             Percent                   0.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  32.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  59.60
#
# locationabbr                                                                                                     VI  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence            NaN
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence            NaN
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence            NaN
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          17.18
#                                                                                     Age-adjusted Prevalence   18.48
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          75.70
#                                                                                     Age-adjusted Prevalence   83.40
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                     NaN
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                     NaN
#
# locationabbr                                                                                                     VT  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          29.31
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          70.24
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          16.41
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          19.37
#                                                                                     Age-adjusted Prevalence   19.94
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          58.86
#                                                                                     Age-adjusted Prevalence   58.43
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   10.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   64.15
#
# locationabbr                                                                                                     WA  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence            NaN
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          51.60
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence            NaN
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          15.74
#                                                                                     Age-adjusted Prevalence   15.36
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          61.58
#                                                                                     Age-adjusted Prevalence   60.28
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   11.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   61.60
#
# locationabbr                                                                                                     WI  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence          29.83
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence          56.67
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence          18.40
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence          22.48
#                                                                                     Age-adjusted Prevalence   22.55
# ...                                                                                                             ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence          62.84
#                                                                                     Age-adjusted Prevalence   61.70
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  100.00
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                   11.00
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                   59.97
#
# locationabbr                                                                                                    WV  \
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         32.01
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         44.62
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         16.85
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         11.59
#                                                                                     Age-adjusted Prevalence  12.95
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         56.33
#                                                                                     Age-adjusted Prevalence  56.24
#         TOB6_0     Proportion of the population protected by a com... %             Percent                  57.40
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  16.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  78.60
#
# locationabbr                                                                                                    WY
# topic   questionid question                                           datavalueunit datavaluetype
# Alcohol ALC1_1     Alcohol use among youth                            %             Crude Prevalence         33.67
#         ALC1_2     Alcohol use before pregnancy                       %             Crude Prevalence         56.30
#         ALC2_1     Binge drinking prevalence among youth              %             Crude Prevalence         20.55
#         ALC2_2     Binge drinking prevalence among adults aged >= ... %             Crude Prevalence         18.92
#                                                                                     Age-adjusted Prevalence  19.06
# ...                                                                                                            ...
# Tobacco TOB3_0     Quit attempts in the past year among current sm... %             Crude Prevalence         57.11
#                                                                                     Age-adjusted Prevalence  55.79
#         TOB6_0     Proportion of the population protected by a com... %             Percent                   0.30
#         TOB8_0     Percent tobacco revenue to fund at CDC recommen... %             Percent                  21.50
#         TOB9_0     Secondary schools that have a comprehensive tob... %             Percent                  46.70
#
# [314 rows x 55 columns]

# %%
#let's look at the question indicators by taking the first 20 characters
df['questionabbr'] = df['question'].str[:20]
df_question_indicators = df.pivot_table(values = 'datavaluealt', index = ['topic','questionid','questionabbr'],columns = 'locationabbr',aggfunc = 'mean',dropna=True).round(2)
df_question_indicators
# Out:
# locationabbr                                AK     AL     AR      AZ     CA  \
# topic   questionid questionabbr
# Alcohol ALC1_1     Alcohol use among yo  23.25  32.38  29.69   34.85  28.33
#         ALC1_2     Alcohol use before p  53.70  45.24  45.04     NaN    NaN
#         ALC2_1     Binge drinking preva  13.76  17.75  12.76   18.93  12.12
#         ALC2_2     Binge drinking preva  19.12  13.42  14.85   15.61  16.44
#         ALC2_3     Binge drinking preva  20.17  12.14  16.29   14.70  17.54
# ...                                        ...    ...    ...     ...    ...
# Tobacco TOB2_2     Current smokeless to   6.71   5.82   6.77    3.09   1.74
#         TOB3_0     Quit attempts in the  60.19  64.94  62.19   60.54  61.87
#         TOB6_0     Proportion of the po  44.97  12.47   0.37  100.00  46.70
#         TOB8_0     Percent tobacco reve  11.50  23.50  15.00   16.50  22.50
#         TOB9_0     Secondary schools th  47.75  68.70  64.58   59.07  65.72
#
# locationabbr                                 CO     CT      DC      DE     FL  \
# topic   questionid questionabbr
# Alcohol ALC1_1     Alcohol use among yo   26.56  30.22   25.12   31.18  29.45
#         ALC1_2     Alcohol use before p   54.44  50.36     NaN   45.47    NaN
#         ALC2_1     Binge drinking preva   14.72  13.52    9.28   15.76  12.78
#         ALC2_2     Binge drinking preva   17.53  16.54   23.64   17.05  15.74
#         ALC2_3     Binge drinking preva   19.64  17.76   31.05   19.62  15.71
# ...                                         ...    ...     ...     ...    ...
# Tobacco TOB2_2     Current smokeless to    3.97   1.71    1.32    2.68   2.90
#         TOB3_0     Quit attempts in the   63.58  66.61   67.05   62.27  65.95
#         TOB6_0     Proportion of the po  100.00   0.00  100.00  100.00   0.00
#         TOB8_0     Percent tobacco reve   18.00   9.00   16.50   11.00  18.50
#         TOB9_0     Secondary schools th   56.10  57.45   40.60   55.60  60.08
#
# locationabbr                                GA     GU      HI      IA     ID  \
# topic   questionid questionabbr
# Alcohol ALC1_1     Alcohol use among yo  28.08  20.66   25.81   24.85  28.15
#         ALC1_2     Alcohol use before p  38.74    NaN   55.01   51.65    NaN
#         ALC2_1     Binge drinking preva  13.30   8.80   12.60   10.98  15.83
#         ALC2_2     Binge drinking preva  14.59  20.88   20.58   20.93  16.01
#         ALC2_3     Binge drinking preva  14.84  15.52   20.36   23.00  15.76
# ...                                        ...    ...     ...     ...    ...
# Tobacco TOB2_2     Current smokeless to   4.38   7.88    2.29    5.75   6.10
#         TOB3_0     Quit attempts in the  65.05  68.91   61.29   56.12  57.42
#         TOB6_0     Proportion of the po   3.13   0.00  100.00  100.00  13.47
#         TOB8_0     Percent tobacco reve  29.50    NaN    9.50   17.50  22.00
#         TOB9_0     Secondary schools th  66.25  58.30   64.55   56.45  49.95
#
# locationabbr                                 IL     IN      KS     KY     LA  \
# topic   questionid questionabbr
# Alcohol ALC1_1     Alcohol use among yo   28.97  29.95   28.32  27.58  36.00
#         ALC1_2     Alcohol use before p   50.89    NaN   54.65  51.09  47.92
#         ALC2_1     Binge drinking preva   11.78  17.40   15.20  13.34  14.33
#         ALC2_2     Binge drinking preva   20.14  16.49   15.99  16.35  17.75
#         ALC2_3     Binge drinking preva   21.25  16.86   16.51  16.32  16.23
# ...                                         ...    ...     ...    ...    ...
# Tobacco TOB2_2     Current smokeless to    3.19   4.59    5.34   7.43   5.42
#         TOB3_0     Quit attempts in the   64.25  60.44   60.46  58.77  63.22
#         TOB6_0     Proportion of the po  100.00  29.07  100.00  33.23  13.37
#         TOB8_0     Percent tobacco reve   16.00  15.00   18.00  18.00  20.50
#         TOB9_0     Secondary schools th   55.27  55.63   49.18  37.90  56.00
#
# locationabbr                                 MA      MD      ME      MI  \
# topic   questionid questionabbr
# Alcohol ALC1_1     Alcohol use among yo   30.24   26.36   23.14   25.71
#         ALC1_2     Alcohol use before p   54.86   43.51   68.05   53.82
#         ALC2_1     Binge drinking preva   14.37   12.86   13.05   13.20
#         ALC2_2     Binge drinking preva   17.42   14.91   19.21   18.65
#         ALC2_3     Binge drinking preva   19.93   17.31   21.59   20.04
# ...                                         ...     ...     ...     ...
# Tobacco TOB2_2     Current smokeless to    2.06    2.19    3.03    3.88
#         TOB3_0     Quit attempts in the   64.00   62.84   59.30   64.17
#         TOB6_0     Proportion of the po  100.00  100.00  100.00  100.00
#         TOB8_0     Percent tobacco reve   10.50   12.00    8.50    9.00
#         TOB9_0     Secondary schools th   60.00   63.62   64.52   58.72
#
# locationabbr                                 MN     MO     MS      MT     NC  \
# topic   questionid questionabbr
# Alcohol ALC1_1     Alcohol use among yo     NaN  33.35  31.04   35.11  26.96
#         ALC1_2     Alcohol use before p   53.12  55.18  49.00   69.80  44.40
#         ALC2_1     Binge drinking preva     NaN  16.10  16.00   18.90  11.70
#         ALC2_2     Binge drinking preva   19.35  18.45  14.45   21.77  14.21
#         ALC2_3     Binge drinking preva   18.15  19.98  11.34   21.89  14.92
# ...                                         ...    ...    ...     ...    ...
# Tobacco TOB2_2     Current smokeless to    4.40   6.16   7.54    8.71   4.69
#         TOB3_0     Quit attempts in the   62.09  58.86  64.58   57.68  64.13
#         TOB6_0     Proportion of the po  100.00  23.60  24.53  100.00   0.10
#         TOB8_0     Percent tobacco reve   10.00  30.00  19.50   12.00  29.00
#         TOB9_0     Secondary schools th   61.35  46.55  71.32   62.42  76.62
#
# locationabbr                                 ND      NE     NH      NJ  \
# topic   questionid questionabbr
# Alcohol ALC1_1     Alcohol use among yo   32.37   23.67  29.33   37.46
#         ALC1_2     Alcohol use before p   60.09   49.90  70.53   47.02
#         ALC2_1     Binge drinking preva   17.83   11.83  17.05   23.00
#         ALC2_2     Binge drinking preva   24.22   19.42  18.46   15.76
#         ALC2_3     Binge drinking preva   26.08   19.97  19.81   16.82
# ...                                         ...     ...    ...     ...
# Tobacco TOB2_2     Current smokeless to    8.22    5.26   2.91    1.88
#         TOB3_0     Quit attempts in the   56.65   60.46  60.12   67.00
#         TOB6_0     Proportion of the po  100.00  100.00   0.00  100.00
#         TOB8_0     Percent tobacco reve   18.50   19.50   8.50   11.00
#         TOB9_0     Secondary schools th   55.58   43.65  67.18   58.20
#
# locationabbr                                 NM     NV      NY     OH     OK  \
# topic   questionid questionabbr
# Alcohol ALC1_1     Alcohol use among yo   25.04  30.82   26.06  29.46  31.16
#         ALC1_2     Alcohol use before p   47.87    NaN   46.23  52.92  48.47
#         ALC2_1     Binge drinking preva   11.82  12.32    9.93  16.10  15.96
#         ALC2_2     Binge drinking preva   14.88  16.19   16.36  18.08  13.77
#         ALC2_3     Binge drinking preva   14.75  16.13   17.52  19.66  13.94
# ...                                         ...    ...     ...    ...    ...
# Tobacco TOB2_2     Current smokeless to    4.55   3.70    2.31   4.99   7.44
#         TOB3_0     Quit attempts in the   61.37  59.77   65.95  60.20  61.32
#         TOB6_0     Proportion of the po  100.00   0.00  100.00  71.50   0.00
#         TOB8_0     Percent tobacco reve   19.50  20.00   12.00  11.50  13.50
#         TOB9_0     Secondary schools th   63.23  58.75   60.63  43.15  58.15
#
# locationabbr                                 OR     PA      PR      RI     SC  \
# topic   questionid questionabbr
# Alcohol ALC1_1     Alcohol use among yo     NaN  28.40   23.66   25.59  26.06
#         ALC1_2     Alcohol use before p   52.41  50.74   40.35   53.37    NaN
#         ALC2_1     Binge drinking preva     NaN  11.48    8.93   11.22  10.72
#         ALC2_2     Binge drinking preva   16.61  17.72   14.34   17.47  15.81
#         ALC2_3     Binge drinking preva   18.77  19.71   12.17   19.65  15.71
# ...                                         ...    ...     ...     ...    ...
# Tobacco TOB2_2     Current smokeless to    4.36   4.76    0.87    1.75   4.03
#         TOB3_0     Quit attempts in the   60.14  63.83   67.90   63.85  65.42
#         TOB6_0     Proportion of the po  100.00   0.00  100.00  100.00  31.43
#         TOB8_0     Percent tobacco reve   12.50  10.50     NaN    8.00  41.50
#         TOB9_0     Secondary schools th   60.78  60.30     NaN   58.40  70.50
#
# locationabbr                                 SD     TN     TX     US      UT  \
# topic   questionid questionabbr
# Alcohol ALC1_1     Alcohol use among yo   29.20  27.12  30.58  30.50   12.14
#         ALC1_2     Alcohol use before p   46.92  43.47  46.93  47.03   27.23
#         ALC2_1     Binge drinking preva   15.75  11.43  12.90  13.88    5.65
#         ALC2_2     Binge drinking preva   21.40  13.28  16.60  17.34   12.18
#         ALC2_3     Binge drinking preva   21.55  13.53  16.48  18.17   10.39
# ...                                         ...    ...    ...    ...     ...
# Tobacco TOB2_2     Current smokeless to    7.25   6.31   3.97   4.29    2.91
#         TOB3_0     Quit attempts in the   58.33  62.23  64.36  60.51   63.78
#         TOB6_0     Proportion of the po  100.00   0.00  38.80  49.35  100.00
#         TOB8_0     Percent tobacco reve   18.50  22.50  19.00    NaN   18.50
#         TOB9_0     Secondary schools th   41.10  49.30  73.73    NaN   59.90
#
# locationabbr                                VA      VI      VT      WA  \
# topic   questionid questionabbr
# Alcohol ALC1_1     Alcohol use among yo  22.49     NaN   29.31     NaN
#         ALC1_2     Alcohol use before p  46.24     NaN   70.24   51.60
#         ALC2_1     Binge drinking preva  11.43     NaN   16.41     NaN
#         ALC2_2     Binge drinking preva  15.32   17.83   19.67   15.55
#         ALC2_3     Binge drinking preva  17.01     NaN   22.09   17.18
# ...                                        ...     ...     ...     ...
# Tobacco TOB2_2     Current smokeless to   3.98     NaN    3.36    3.44
#         TOB3_0     Quit attempts in the  63.28   79.55   58.65   60.93
#         TOB6_0     Proportion of the po   0.00  100.00  100.00  100.00
#         TOB8_0     Percent tobacco reve  32.00     NaN   10.50   11.00
#         TOB9_0     Secondary schools th  59.60     NaN   64.15   61.60
#
# locationabbr                                 WI     WV     WY
# topic   questionid questionabbr
# Alcohol ALC1_1     Alcohol use among yo   29.83  32.01  33.67
#         ALC1_2     Alcohol use before p   56.67  44.62  56.30
#         ALC2_1     Binge drinking preva   18.40  16.85  20.55
#         ALC2_2     Binge drinking preva   22.52  12.28  18.99
#         ALC2_3     Binge drinking preva   26.98  10.37  17.27
# ...                                         ...    ...    ...
# Tobacco TOB2_2     Current smokeless to    4.25   9.15  10.26
#         TOB3_0     Quit attempts in the   62.27  56.29  56.45
#         TOB6_0     Proportion of the po  100.00  57.40   0.30
#         TOB8_0     Percent tobacco reve   11.00  16.50  21.50
#         TOB9_0     Secondary schools th   59.97  78.60  46.70
#
# [193 rows x 55 columns]

# %%
#https://seaborn.pydata.org/generated/seaborn.diverging_palette.html
new_question_indicators = df_question_indicators.transpose().corr()
mask = np.zeros_like(new_question_indicators,dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f,ax = plt.subplots(figsize = (150, 150))
f.suptitle('complete chronic diseases indicators correlation', x=0.4,y=0.85,fontsize=150)
ax.tick_params(labelsize = 45)
cmap = sns.diverging_palette(220,20,as_cmap=True)
sns.heatmap(new_question_indicators,mask=mask,cmap=cmap,vmax=0.3,center=0,square=True,linewidths=2,cbar_kws={'shrink':0.3})
# Out:
# <AxesSubplot:xlabel='topic-questionid-questionabbr', ylabel='topic-questionid-questionabbr'>

# %%
df['question'].value_counts()
# Out:
# Hospitalization for chronic obstructive pulmonary disease as any diagnosis among Medicare-eligible persons aged >= 65 years             11232
# Hospitalization for chronic obstructive pulmonary disease as first-listed diagnosis among Medicare-eligible persons aged >= 65 years    11232
# Hospitalization for hip fracture among Medicare-eligible persons aged >= 65 years                                                       11232
# Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years                                                      11232
# Mortality from coronary heart disease                                                                                                   11043
#                                                                                                                                         ...
# Health insurance coverage before pregnancy                                                                                                 55
# Prevalence of pre-pregnancy diabetes                                                                                                       55
# Postpartum depressive symptoms                                                                                                             55
# Pre-pregnancy hypertension                                                                                                                 55
# Prevalence of gestational diabetes                                                                                                         52
# Name: question, Length: 203, dtype: int64

# %%
df.datavalue.dtypes
#https://stackoverflow.com/questions/37561991/what-is-dtypeo-in-pandas
# Out:
# dtype('O')

# %%
#from the giant heatmap above we can see some areas in the cardiovascular disease and cancer which have higher correlations, let's zoom in and try to find out more information about Cardiovascular Disease
df_zoom = df.drop(columns = ['datasource','datavaluefootnotesymbol','datavaluefootnote','geolocation','locationid','topicid','questionid','datavaluetypeid','stratificationcategoryid1','stratificationid1','questionabbr'])
df_zoom
# Out:
#         yearstart  yearend locationabbr   locationdesc    topic  \
# 0            2010     2014           AK         Alaska   Cancer
# 1            2010     2014           AK         Alaska   Cancer
# 2            2010     2014           AZ        Arizona   Cancer
# 3            2008     2012           NY       New York   Cancer
# 4            2009     2013           NY       New York   Cancer
# ...           ...      ...          ...            ...      ...
# 956633       2012     2012           NH  New Hampshire  Tobacco
# 956634       2017     2017           SD   South Dakota  Tobacco
# 956635       2011     2011           WI      Wisconsin  Tobacco
# 956636       2019     2019           MI       Michigan  Tobacco
# 956637       2015     2015           OH           Ohio  Tobacco
#
#                                                  question datavalueunit  \
# 0        Cancer of the oral cavity and pharynx, mortality           NaN
# 1        Cancer of the oral cavity and pharynx, mortality           NaN
# 2        Cancer of the oral cavity and pharynx, mortality           NaN
# 3        Cancer of the oral cavity and pharynx, mortality           NaN
# 4        Cancer of the oral cavity and pharynx, mortality           NaN
# ...                                                   ...           ...
# 956633  Quit attempts in the past year among current s...             %
# 956634  Quit attempts in the past year among current s...             %
# 956635  Quit attempts in the past year among current s...             %
# 956636  Quit attempts in the past year among current s...             %
# 956637  Quit attempts in the past year among current s...             %
#
#                   datavaluetype datavalue  datavaluealt  lowconfidencelimit  \
# 0         Average Annual Number         3           3.0                 NaN
# 1         Average Annual Number        15          15.0                 NaN
# 2         Average Annual Number       109         109.0                 NaN
# 3         Average Annual Number       329         329.0                 NaN
# 4         Average Annual Number       336         336.0                 NaN
# ...                         ...       ...           ...                 ...
# 956633         Crude Prevalence       NaN           NaN                 NaN
# 956634  Age-adjusted Prevalence        59          59.0                51.4
# 956635         Crude Prevalence      91.4          91.4                81.8
# 956636         Crude Prevalence      51.4          51.4                36.0
# 956637  Age-adjusted Prevalence      72.3          72.3                61.9
#
#         highconfidencelimit stratificationcategory1            stratification1
# 0                       NaN                  Gender                     Female
# 1                       NaN                 Overall                    Overall
# 2                       NaN                  Gender                       Male
# 3                       NaN                  Gender                       Male
# 4                       NaN                  Gender                       Male
# ...                     ...                     ...                        ...
# 956633                  NaN          Race/Ethnicity        Other, non-Hispanic
# 956634                 66.3                  Gender                     Female
# 956635                 96.2          Race/Ethnicity        Other, non-Hispanic
# 956636                 66.5          Race/Ethnicity  Multiracial, non-Hispanic
# 956637                 80.8          Race/Ethnicity        Black, non-Hispanic
#
# [956638 rows x 14 columns]

# %%
pd.crosstab(cardiovascular_disease['question'], cardiovascular_disease['locationabbr'])
# Out:
# locationabbr                                         AK   AL   AR   AZ   CA  \
# question
# Awareness of high blood pressure among adults a...   80   80   80   80   80
# Awareness of high blood pressure among women ag...   30   30   30   30   30
# Cholesterol screening among adults aged >= 18 y...   80   80   80   80   80
# High cholesterol prevalence among adults aged >...   80   80   80   80   80
# Hospitalization for acute myocardial infarction     102  102  144  144  123
# Hospitalization for heart failure among Medicar...  216  216  216  216  216
# Hospitalization for stroke                          102  102  144  144  123
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Mortality from cerebrovascular disease (stroke)     216  216  216  216  216
# Mortality from coronary heart disease               216  216  216  216  216
# Mortality from diseases of the heart                216  216  216  216  216
# Mortality from heart failure                        192  192  192  192  192
# Mortality from total cardiovascular diseases        216  216  216  216  216
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pre-pregnancy hypertension                            1    1    1    1    1
# Taking medicine for high blood pressure control...   80   80   80   80   80
#
# locationabbr                                         CO   CT   DC   DE   FL  \
# question
# Awareness of high blood pressure among adults a...   80   80   80   80   80
# Awareness of high blood pressure among women ag...   30   30   30   30   30
# Cholesterol screening among adults aged >= 18 y...   80   80   80   80   80
# High cholesterol prevalence among adults aged >...   80   80   80   80   80
# Hospitalization for acute myocardial infarction     144  102  102  102  144
# Hospitalization for heart failure among Medicar...  216  216  216  216  216
# Hospitalization for stroke                          144  102  102  102  144
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Mortality from cerebrovascular disease (stroke)     216  216  216  216  216
# Mortality from coronary heart disease               216  216  216  216  216
# Mortality from diseases of the heart                216  216  216  216  216
# Mortality from heart failure                        192  192  192  192  192
# Mortality from total cardiovascular diseases        216  216  216  216  216
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pre-pregnancy hypertension                            1    1    1    1    1
# Taking medicine for high blood pressure control...   80   80   80   80   80
#
# locationabbr                                         GA   GU   HI   IA   ID  \
# question
# Awareness of high blood pressure among adults a...   80   80   80   80   80
# Awareness of high blood pressure among women ag...   30   30   30   30   30
# Cholesterol screening among adults aged >= 18 y...   80   80   80   80   80
# High cholesterol prevalence among adults aged >...   80   80   80   80   80
# Hospitalization for acute myocardial infarction     102  102  144  144  102
# Hospitalization for heart failure among Medicar...  216    0  216  216  216
# Hospitalization for stroke                          102  102  144  144  102
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Mortality from cerebrovascular disease (stroke)     216    0  216  216  216
# Mortality from coronary heart disease               216    0  216  216  216
# Mortality from diseases of the heart                216    0  216  216  216
# Mortality from heart failure                        192    0  192  192  192
# Mortality from total cardiovascular diseases        216    0  216  216  216
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pre-pregnancy hypertension                            1    1    1    1    1
# Taking medicine for high blood pressure control...   80   80   80   80   80
#
# locationabbr                                         IL   IN   KS   KY   LA  \
# question
# Awareness of high blood pressure among adults a...   80   80   80   80   80
# Awareness of high blood pressure among women ag...   30   30   30   30   30
# Cholesterol screening among adults aged >= 18 y...   80   80   80   80   80
# High cholesterol prevalence among adults aged >...   80   80   80   80   80
# Hospitalization for acute myocardial infarction     102  102  102  144  102
# Hospitalization for heart failure among Medicar...  216  216  216  216  216
# Hospitalization for stroke                          102  102  102  144  102
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Mortality from cerebrovascular disease (stroke)     216  216  216  216  216
# Mortality from coronary heart disease               216  216  216  216  216
# Mortality from diseases of the heart                216  216  216  216  216
# Mortality from heart failure                        192  192  192  192  192
# Mortality from total cardiovascular diseases        216  216  216  216  216
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pre-pregnancy hypertension                            1    1    1    1    1
# Taking medicine for high blood pressure control...   80   80   80   80   80
#
# locationabbr                                         MA   MD   ME   MI   MN  \
# question
# Awareness of high blood pressure among adults a...   80   80   80   80   80
# Awareness of high blood pressure among women ag...   30   30   30   30   30
# Cholesterol screening among adults aged >= 18 y...   80   80   80   80   80
# High cholesterol prevalence among adults aged >...   80   80   80   80   80
# Hospitalization for acute myocardial infarction     123  123  102  144  102
# Hospitalization for heart failure among Medicar...  216  216  216  216  216
# Hospitalization for stroke                          123  123  102  144  102
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Mortality from cerebrovascular disease (stroke)     216  216  216  216  216
# Mortality from coronary heart disease               216  216  216  216  216
# Mortality from diseases of the heart                216  216  216  216  216
# Mortality from heart failure                        192  192  192  192  192
# Mortality from total cardiovascular diseases        216  216  216  216  216
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pre-pregnancy hypertension                            1    1    1    1    1
# Taking medicine for high blood pressure control...   80   80   80   80   80
#
# locationabbr                                         MO   MS   MT   NC   ND  \
# question
# Awareness of high blood pressure among adults a...   80   80   80   80   80
# Awareness of high blood pressure among women ag...   30   30   30   30   30
# Cholesterol screening among adults aged >= 18 y...   80   80   80   80   80
# High cholesterol prevalence among adults aged >...   80   80   80   80   80
# Hospitalization for acute myocardial infarction     102  123  102  144  102
# Hospitalization for heart failure among Medicar...  216  216  216  216  216
# Hospitalization for stroke                          102  123  102  144  102
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Mortality from cerebrovascular disease (stroke)     216  216  216  216  216
# Mortality from coronary heart disease               216  216  216  216  216
# Mortality from diseases of the heart                216  216  216  216  216
# Mortality from heart failure                        192  192  192  192  192
# Mortality from total cardiovascular diseases        216  216  216  216  216
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pre-pregnancy hypertension                            1    1    1    1    1
# Taking medicine for high blood pressure control...   80   80   80   80   80
#
# locationabbr                                         NE   NH   NJ   NM   NV  \
# question
# Awareness of high blood pressure among adults a...   80   80   80   80   80
# Awareness of high blood pressure among women ag...   30   30   30   30   30
# Cholesterol screening among adults aged >= 18 y...   80   80   80   80   80
# High cholesterol prevalence among adults aged >...   80   80   80   80   80
# Hospitalization for acute myocardial infarction     144  102  144  144  144
# Hospitalization for heart failure among Medicar...  216  216  216  216  216
# Hospitalization for stroke                          144  102  144  144  144
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Mortality from cerebrovascular disease (stroke)     216  216  216  216  216
# Mortality from coronary heart disease               216  216  216  216  216
# Mortality from diseases of the heart                216  216  216  216  216
# Mortality from heart failure                        192  192  192  192  192
# Mortality from total cardiovascular diseases        216  216  216  216  216
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pre-pregnancy hypertension                            1    1    1    1    1
# Taking medicine for high blood pressure control...   80   80   80   80   80
#
# locationabbr                                         NY   OH   OK   OR   PA  \
# question
# Awareness of high blood pressure among adults a...   80   80   80   80   80
# Awareness of high blood pressure among women ag...   30   30   30   30   30
# Cholesterol screening among adults aged >= 18 y...   80   80   80   80   80
# High cholesterol prevalence among adults aged >...   80   80   80   80   80
# Hospitalization for acute myocardial infarction     144  102  102  144  102
# Hospitalization for heart failure among Medicar...  216  216  216  216  216
# Hospitalization for stroke                          144  102  102  144  102
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Mortality from cerebrovascular disease (stroke)     216  216  216  216  216
# Mortality from coronary heart disease               216  216  216  216  216
# Mortality from diseases of the heart                216  216  216  216  216
# Mortality from heart failure                        192  192  192  192  192
# Mortality from total cardiovascular diseases        216  216  216  216  216
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pre-pregnancy hypertension                            1    1    1    1    1
# Taking medicine for high blood pressure control...   80   80   80   80   80
#
# locationabbr                                         PR   RI   SC   SD   TN  \
# question
# Awareness of high blood pressure among adults a...   80   80   80   80   80
# Awareness of high blood pressure among women ag...   30   30   30   30   30
# Cholesterol screening among adults aged >= 18 y...   80   80   80   80   80
# High cholesterol prevalence among adults aged >...   80   80   80   80   80
# Hospitalization for acute myocardial infarction     102  123  144  144  102
# Hospitalization for heart failure among Medicar...    0  216  216  216  216
# Hospitalization for stroke                          102  123  144  144  102
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Mortality from cerebrovascular disease (stroke)       0  216  216  216  216
# Mortality from coronary heart disease                 0  216  216  216  216
# Mortality from diseases of the heart                  0  216  216  216  216
# Mortality from heart failure                          0  192  192  192  192
# Mortality from total cardiovascular diseases          0  216  216  216  216
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pre-pregnancy hypertension                            1    1    1    1    1
# Taking medicine for high blood pressure control...   80   80   80   80   80
#
# locationabbr                                         TX   US   UT   VA   VI  \
# question
# Awareness of high blood pressure among adults a...   80   30   80   80   80
# Awareness of high blood pressure among women ag...   30    5   30   30   30
# Cholesterol screening among adults aged >= 18 y...   80   30   80   80   80
# High cholesterol prevalence among adults aged >...   80   30   80   80   80
# Hospitalization for acute myocardial infarction     102   12  123  102  102
# Hospitalization for heart failure among Medicar...  216  216  216  216    0
# Hospitalization for stroke                          102   12  123  102  102
# Influenza vaccination among noninstitutionalize...  144   54  144  144  144
# Influenza vaccination among noninstitutionalize...  144   54  144  144  144
# Mortality from cerebrovascular disease (stroke)     216   27  216  216    0
# Mortality from coronary heart disease               216   27  216  216    0
# Mortality from diseases of the heart                216   27  216  216    0
# Mortality from heart failure                        192   24  192  192    0
# Mortality from total cardiovascular diseases        216   27  216  216    0
# Pneumococcal vaccination among noninstitutional...  144   54  144  144  144
# Pneumococcal vaccination among noninstitutional...  144   54  144  144  144
# Pre-pregnancy hypertension                            1    1    1    1    1
# Taking medicine for high blood pressure control...   80   30   80   80   80
#
# locationabbr                                         VT   WA   WI   WV   WY
# question
# Awareness of high blood pressure among adults a...   80   80   80   80   80
# Awareness of high blood pressure among women ag...   30   30   30   30   30
# Cholesterol screening among adults aged >= 18 y...   80   80   80   80   80
# High cholesterol prevalence among adults aged >...   80   80   80   80   80
# Hospitalization for acute myocardial infarction     144  144  144  144  102
# Hospitalization for heart failure among Medicar...  216  216  216  216  216
# Hospitalization for stroke                          144  144  144  144  102
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Influenza vaccination among noninstitutionalize...  144  144  144  144  144
# Mortality from cerebrovascular disease (stroke)     216  216  216  216  216
# Mortality from coronary heart disease               216  216  216  216  216
# Mortality from diseases of the heart                216  216  216  216  216
# Mortality from heart failure                        192  192  192  192  192
# Mortality from total cardiovascular diseases        216  216  216  216  216
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pneumococcal vaccination among noninstitutional...  144  144  144  144  144
# Pre-pregnancy hypertension                            1    1    1    1    1
# Taking medicine for high blood pressure control...   80   80   80   80   80

# %%
df_zoom.dropna(subset=['datavalueunit'], inplace=True)
df_zoom.reset_index(drop=True, inplace=True)
df_zoom
# Out:
#         yearstart  yearend locationabbr   locationdesc  \
# 0            2009     2009           US  United States
# 1            2018     2018           GU           Guam
# 2            2012     2012           VA       Virginia
# 3            2019     2019           NY       New York
# 4            2016     2016           LA      Louisiana
# ...           ...      ...          ...            ...
# 830933       2012     2012           NH  New Hampshire
# 830934       2017     2017           SD   South Dakota
# 830935       2011     2011           WI      Wisconsin
# 830936       2019     2019           MI       Michigan
# 830937       2015     2015           OH           Ohio
#
#                          topic  \
# 0       Overarching Conditions
# 1                      Alcohol
# 2                      Tobacco
# 3                      Tobacco
# 4                      Tobacco
# ...                        ...
# 830933                 Tobacco
# 830934                 Tobacco
# 830935                 Tobacco
# 830936                 Tobacco
# 830937                 Tobacco
#
#                                                  question datavalueunit  \
# 0                         Life expectancy at age 65 years         Years
# 1                            Alcohol use before pregnancy             %
# 2       Quit attempts in the past year among current s...             %
# 3       Quit attempts in the past year among current s...             %
# 4       Quit attempts in the past year among current s...             %
# ...                                                   ...           ...
# 830933  Quit attempts in the past year among current s...             %
# 830934  Quit attempts in the past year among current s...             %
# 830935  Quit attempts in the past year among current s...             %
# 830936  Quit attempts in the past year among current s...             %
# 830937  Quit attempts in the past year among current s...             %
#
#                   datavaluetype datavalue  datavaluealt  lowconfidencelimit  \
# 0                        Number      17.7          17.7                 NaN
# 1              Crude Prevalence       NaN           NaN                 NaN
# 2              Crude Prevalence      67.2          67.2                62.6
# 3              Crude Prevalence      55.3          55.3                50.3
# 4              Crude Prevalence      60.8          60.8                53.7
# ...                         ...       ...           ...                 ...
# 830933         Crude Prevalence       NaN           NaN                 NaN
# 830934  Age-adjusted Prevalence        59          59.0                51.4
# 830935         Crude Prevalence      91.4          91.4                81.8
# 830936         Crude Prevalence      51.4          51.4                36.0
# 830937  Age-adjusted Prevalence      72.3          72.3                61.9
#
#         highconfidencelimit stratificationcategory1            stratification1
# 0                       NaN                  Gender                       Male
# 1                       NaN                 Overall                    Overall
# 2                      71.4                  Gender                     Female
# 3                      60.3                  Gender                     Female
# 4                      67.5                  Gender                       Male
# ...                     ...                     ...                        ...
# 830933                  NaN          Race/Ethnicity        Other, non-Hispanic
# 830934                 66.3                  Gender                     Female
# 830935                 96.2          Race/Ethnicity        Other, non-Hispanic
# 830936                 66.5          Race/Ethnicity  Multiracial, non-Hispanic
# 830937                 80.8          Race/Ethnicity        Black, non-Hispanic
#
# [830938 rows x 14 columns]

# %%
#Merge year start with year end
print((df_zoom['yearstart']==df_zoom['yearend']).value_counts())
df_zoom['year']=df_zoom['yearstart']

df_zoom.drop(['yearstart','yearend'], axis=1, inplace=True)
df_zoom.head()
# Out:
# True     749856
# False     81082
# dtype: int64
#   locationabbr   locationdesc                   topic  \
# 0           US  United States  Overarching Conditions
# 1           GU           Guam                 Alcohol
# 2           VA       Virginia                 Tobacco
# 3           NY       New York                 Tobacco
# 4           LA      Louisiana                 Tobacco
#
#                                             question datavalueunit  \
# 0                    Life expectancy at age 65 years         Years
# 1                       Alcohol use before pregnancy             %
# 2  Quit attempts in the past year among current s...             %
# 3  Quit attempts in the past year among current s...             %
# 4  Quit attempts in the past year among current s...             %
#
#       datavaluetype datavalue  datavaluealt  lowconfidencelimit  \
# 0            Number      17.7          17.7                 NaN
# 1  Crude Prevalence       NaN           NaN                 NaN
# 2  Crude Prevalence      67.2          67.2                62.6
# 3  Crude Prevalence      55.3          55.3                50.3
# 4  Crude Prevalence      60.8          60.8                53.7
#
#    highconfidencelimit stratificationcategory1 stratification1  year
# 0                  NaN                  Gender            Male  2009
# 1                  NaN                 Overall         Overall  2018
# 2                 71.4                  Gender          Female  2012
# 3                 60.3                  Gender          Female  2019
# 4                 67.5                  Gender            Male  2016

# %%
df_zoom=df_zoom[df_zoom['datavalue']!=' ']
df_zoom.reset_index(drop=True, inplace=True)
print(df_zoom['datavalue'].value_counts())
print(df_zoom.shape)
# Out:
# 1.0       1607
# 3.5       1406
# 3.6       1379
# 2.9       1365
# 3.8       1335
#           ...
# 35.89        1
# 36.14        1
# 257.15       1
# 39.39        1
# 5.84         1
# Name: datavalue, Length: 27929, dtype: int64
# (830938, 13)

# %%
#df.fillna(df['datavalue'].mean(), inplace=True)
df_zoom["datavalue"] = pd.to_numeric(df_zoom['datavalue'])
df_zoom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830938 entries, 0 to 830937
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   locationabbr             830938 non-null  object
#  1   locationdesc             830938 non-null  object
#  2   topic                    830938 non-null  object
#  3   question                 830938 non-null  object
#  4   datavalueunit            830938 non-null  object
#  5   datavaluetype            830938 non-null  object
#  6   datavalue                558749 non-null  float64
#  7   datavaluealt             558749 non-null  float64
#  8   lowconfidencelimit       548520 non-null  float64
#  9   highconfidencelimit      548520 non-null  float64
#  10  stratificationcategory1  830938 non-null  object
#  11  stratification1          830938 non-null  object
#  12  year                     830938 non-null  int64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 82.4+ MB

# %%
#Separating into different dataframes depending on Questions
#df_zoom_cardio
df_zoom_cardio=df_zoom[df_zoom['question']=='Mortality from total cardiovascular diseases']
#df_zoom_heart
df_zoom_heart=df_zoom[df_zoom['question']=='Mortality from diseases of the heart']
#df_zoom_heart_failure
df_zoom_heart_failure=df_zoom[df_zoom['question']=='Mortality from heart failure']

# %%
#lets see the number of deaths by total cardiovascular diseases trough the years for male and female and overall
df_zoom_final=df_zoom_cardio[df_zoom_cardio['stratification1']=='Overall'].groupby('year').sum()
df_zoom_final.rename(columns={'datavalue':'DV_overall'},inplace=True)

df_zoom_cardio_male=df_zoom_cardio[df_zoom_cardio['stratification1']=='Male'].groupby('year').sum()
df_zoom_cardio_male.rename(columns={'datavalue':'DV_male'},inplace=True)

df_zoom_cardio_female=df_zoom_cardio[df_zoom_cardio['stratification1']=='Female'].groupby('year').sum()
df_zoom_cardio_female.rename(columns={'datavalue':'DV_female'},inplace=True)

df_zoom_cardio_merged=pd.merge(df_zoom_final,df_zoom_cardio_male,on='year', how='inner')
df_zoom_cardio_merged=pd.merge(df_zoom_cardio_merged,df_zoom_cardio_female,on='year', how='inner')
df_zoom_cardio_merged=df_zoom_cardio_merged[['DV_overall','DV_male','DV_female']]
df_zoom_cardio_merged
# Out:
#       DV_overall  DV_male  DV_female
# year
# 2010     25472.5  27479.8    22961.6
# 2011     24968.4  27012.1    22400.5
# 2012     24836.7  26888.6    22265.5
# 2013     24875.7  27135.2    22104.5
# 2014     24857.8  27190.7    22008.3
# 2015     25294.9  27547.3    22490.1
# 2016     25200.7  27626.5    22223.9
# 2017     25368.2  27891.2    22307.2
# 2018     25346.0  27977.2    22153.8

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]

lifespan = [2, 8, 70, 1.5, 25, 12, 28]

index = ['snail', 'pig', 'elephant',

         'rabbit', 'giraffe', 'coyote', 'horse']

df = pd.DataFrame({'speed': speed,

                   'lifespan': lifespan}, index=index)

ax = df.plot.bar(rot=0)

# %%
#let's plot the cardio disease plot
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

df_bar_plot = pd.DataFrame({'Overall': df_zoom_cardio_merged['DV_overall'],'Male': df_zoom_cardio_merged['DV_male'],'Female': df_zoom_cardio_merged['DV_female']}, index= df_zoom_cardio_merged.index)
ax = df_bar_plot.plot.bar(rot=0, color={"green": "Overall", "red":"Male", "blue":"Female"})

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]

lifespan = [2, 8, 70, 1.5, 25, 12, 28]

index = ['snail', 'pig', 'elephant',

         'rabbit', 'giraffe', 'coyote', 'horse']

df = pd.DataFrame({'speed': speed,

                   'lifespan': lifespan}, index=index)

ax = df.plot.bar(rot=0)

# %%
#let's normalize this for a clearer and neater picture
x=df_zoom_cardio_merged.values 
min_max_scaler = preprocessing.StandardScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_zoom_cardio_merged_normalized = pd.DataFrame(x_scaled, columns=df_zoom_cardio_merged.columns,index=df_zoom_cardio_merged.index)
df_zoom_cardio_merged_normalized
# Out:
#       DV_overall   DV_male  DV_female
# year
# 2010    1.424127  0.174989   2.409170
# 2011   -0.707131 -1.118165   0.289277
# 2012   -1.263939 -1.459632  -0.220767
# 2013   -1.099053 -0.777803  -0.829042
# 2014   -1.174731 -0.624350  -1.192495
# 2015    0.673261  0.361621   0.627795
# 2016    0.274998  0.580603  -0.377936
# 2017    0.983163  1.312477  -0.063220
# 2018    0.889304  1.550260  -0.642781

# %%
#better normalized plot of teh cardio disease
ax = df_zoom_cardio_merged_normalized.plot.bar(rot=0,color={"green":"DV_overall", "red":"DV_male", "blue":"DV_female"})

# %%
#another graph showing the cardiovascular disease deaths throughout the years
df_zoom_cardio_merged_normalized_plot = pd.DataFrame({'Overall': df_zoom_cardio_merged_normalized['DV_overall'],
                    'Male': df_zoom_cardio_merged_normalized['DV_male'],
                       'Female': df_zoom_cardio_merged_normalized['DV_female']}, index= df_zoom_cardio_merged_normalized.index)
ax1 = df_zoom_cardio_merged_normalized_plot.plot.line(rot=0,color={"Overall": "green", "Male": "red", "Female":"blue"})
ax1.xaxis.set_major_locator(plt.MaxNLocator(4))
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000001D450B93B80> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     136             def post_execute():
#     137                 if matplotlib.is_interactive():
# --> 138                     draw_all()
#     139
#     140             # IPython >= 2
#
# ~\anaconda3\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     136         for manager in cls.get_all_fig_managers():
#     137             if force or manager.canvas.figure.stale:
# --> 138                 manager.canvas.draw_idle()
#     139
#     140
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2010         if not self._is_idle_drawing:
#    2011             with self._idle_draw_cntx():
# -> 2012                 self.draw(*args, **kwargs)
#    2013
#    2014     @cbook.deprecated("3.2")
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\lines.py in draw(self, renderer)
#     765                 gc.set_url(self.get_url())
#     766
# --> 767                 lc_rgba = mcolors.to_rgba(self._color, self._alpha)
#     768                 gc.set_foreground(lc_rgba, isRGBA=True)
#     769
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     187         rgba = None
#     188     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 189         rgba = _to_rgba_no_colorcycle(c, alpha)
#     190         try:
#     191             _colors_full_map.cache[c, alpha] = rgba
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     258                     f"Value must be within 0-1 range")
#     259             return c, c, c, alpha if alpha is not None else 1.
# --> 260         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     261     # tuple color.
#     262     if not np.iterable(c):
#
# ValueError: Invalid RGBA argument: 'Overall'

# %%
#let's see the total deaths by total cardiovascular disease types troughout the years
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html
df_zoom_final_cardio=df_zoom_cardio[df_zoom_cardio['stratification1']=='Overall'].groupby('year').sum()
df_zoom_final_heart=df_zoom_heart[df_zoom_heart['stratification1']=='Overall'].groupby('year').sum()
df_zoom_final_heart_failure=df_zoom_heart_failure[df_zoom_heart_failure['stratification1']=='Overall'].groupby('year').sum()
df_zoom_cardio_overall_final = pd.DataFrame({'Mortality from total cardiovascular diseases': df_zoom_final_cardio['datavalue'],
                    'Mortality from diseases of the heart': df_zoom_final_heart['datavalue'],
                       'Mortality from heart failure': df_zoom_final_heart_failure['datavalue']}, index= df_zoom_final_cardio.index)
x=df_zoom_cardio_overall_final.values 
min_max_scaler = preprocessing.StandardScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_zoom_cardio_overall_final_normalized = pd.DataFrame(x_scaled, columns=df_zoom_cardio_overall_final.columns,index=df_zoom_cardio_overall_final.index)
df_zoom_cardio_overall_final_normalized  
ax = df_zoom_cardio_overall_final_normalized.plot.bar(rot=0,color={"Mortality from total cardiovascular diseases": "green", "Mortality from diseases of the heart": "blue", "Mortality from heart failure":"red"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     324         try:
# --> 325             result = np.array([to_rgba(cc, alpha) for cc in c])
#     326         except ValueError as err:
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in <listcomp>(.0)
#     324         try:
# --> 325             result = np.array([to_rgba(cc, alpha) for cc in c])
#     326         except ValueError as err:
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     188     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 189         rgba = _to_rgba_no_colorcycle(c, alpha)
#     190         try:
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     259             return c, c, c, alpha if alpha is not None else 1.
# --> 260         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     261     # tuple color.
#
# ValueError: Invalid RGBA argument: 'M'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-3bf3b81d4027> in <module>
#      12 df_zoom_cardio_overall_final_normalized = pd.DataFrame(x_scaled, columns=df_zoom_cardio_overall_final.columns,index=df_zoom_cardio_overall_final.index)
#      13 df_zoom_cardio_overall_final_normalized
# ---> 14 ax = df_zoom_cardio_overall_final_normalized.plot.bar(rot=0,color={"Mortality from total cardiovascular diseases": "green", "Mortality from diseases of the heart": "blue", "Mortality from heart failure":"red"})
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1001             >>> ax = df.plot.bar(x='lifespan', rot=0)
#    1002         """
# -> 1003         return self(kind="bar", x=x, y=y, **kwargs)
#    1004
#    1005     def barh(self, x=None, y=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     261         self._compute_plot_data()
#     262         self._setup_subplots()
# --> 263         self._make_plot()
#     264         self._add_table()
#     265         self._make_legend()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1395             else:
#    1396                 w = self.bar_width / K
# -> 1397                 rect = self._plot(
#    1398                     ax,
#    1399                     self.ax_pos + (i + 0.5) * w,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1328     @classmethod
#    1329     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1330         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1331
#    1332     @property
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2441
#    2442         linewidth = itertools.cycle(np.atleast_1d(linewidth))
# -> 2443         color = itertools.chain(itertools.cycle(mcolors.to_rgba_array(color)),
#    2444                                 # Fallback if color == "none".
#    2445                                 itertools.repeat('none'))
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     325             result = np.array([to_rgba(cc, alpha) for cc in c])
#     326         except ValueError as err:
# --> 327             raise ValueError(
#     328                 "'%s' is neither a valid single color nor a color sequence "
#     329                 "consisting of single character color specifiers such as "
#
# ValueError: 'Mortality from total cardiovascular diseases' is neither a valid single color nor a color sequence consisting of single character color specifiers such as 'rgb'. Note also that the latter is deprecated.

# %%
# another graph showing the same information
ax1 = df_zoom_cardio_overall_final_normalized.plot.line(rot=0,color={"Mortality from total cardiovascular diseases": "green", "Mortality from diseases of the heart": "blue", "Mortality from heart failure":"red"})
ax1.xaxis.set_major_locator(plt.MaxNLocator(4))

# %%
# heart failure progressed at an alarming rate from 2015 onwards! Let's investigate this further

df_zoom_final_heart_failure=df_zoom_heart_failure[df_zoom_heart_failure['stratification1']=='Overall'].groupby('year').sum()
df_zoom_final_heart_failure.rename(columns={'datavalue':'DV_overall'},inplace=True)

df_zoom_heart_failure_male=df_zoom_heart_failure[df_zoom_heart_failure['stratification1']=='Male'].groupby('year').sum()
df_zoom_heart_failure_male.rename(columns={'datavalue':'DV_male'},inplace=True)

df_zoom_heart_failure_female=df_zoom_heart_failure[df_zoom_heart_failure['stratification1']=='Female'].groupby('year').sum()
df_zoom_heart_failure_female.rename(columns={'datavalue':'DV_female'},inplace=True)

df_zoom_heart_failure_merged=pd.merge(df_zoom_final_heart_failure,df_zoom_heart_failure_male,on='year', how='inner')
df_zoom_heart_failure_merged=pd.merge(df_zoom_heart_failure_merged,df_zoom_heart_failure_female,on='year', how='inner')
df_zoom_heart_failure_merged=df_zoom_heart_failure_merged[['DV_overall','DV_male','DV_female']]
df_zoom_heart_failure_merged

# %%
#let's normalize this for a clearer and neater picture
x=df_zoom_heart_failure_merged.values 
min_max_scaler = preprocessing.StandardScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_zoom_heart_failure_merged_normalized = pd.DataFrame(x_scaled, columns=df_zoom_heart_failure_merged.columns,index=df_zoom_heart_failure_merged.index)
df_zoom_heart_failure_merged_normalized

# %%
#better normalized plot of the heart failure deaths
ax = df_zoom_heart_failure_merged_normalized.plot.bar(rot=0,color={"DV_overall": "green", "DV_male": "red", "DV_female":"blue"})

# %%
#another graph showing the heart failure deaths throughout the years
#we can see that deaths went ub for both male and female from 2016
df_zoom_heart_failure_merged_normalized_plot = pd.DataFrame({'Overall': df_zoom_heart_failure_merged_normalized['DV_overall'],
                    'Male': df_zoom_heart_failure_merged_normalized['DV_male'],
                       'Female': df_zoom_heart_failure_merged_normalized['DV_female']}, index= df_zoom_heart_failure_merged_normalized.index)
ax1 = df_zoom_heart_failure_merged_normalized_plot.plot.line(rot=0,color={"Overall": "green", "Male": "red", "Female":"blue"})
ax1.xaxis.set_major_locator(plt.MaxNLocator(4))

# %%
df_zoom_final_heart=df_zoom_heart[df_zoom_heart['stratification1']=='Overall'].groupby('year').sum()
df_zoom_final_heart.rename(columns={'datavalue':'DV_overall'},inplace=True)

df_zoom_heart_male=df_zoom_heart[df_zoom_heart['stratification1']=='Male'].groupby('year').sum()
df_zoom_heart_male.rename(columns={'datavalue':'DV_male'},inplace=True)

df_zoom_heart_female=df_zoom_heart[df_zoom_heart['stratification1']=='Female'].groupby('year').sum()
df_zoom_heart_female.rename(columns={'datavalue':'DV_female'},inplace=True)

df_zoom_heart_merged=pd.merge(df_zoom_final_heart,df_zoom_heart_male,on='year', how='inner')
df_zoom_heart_merged=pd.merge(df_zoom_heart_merged,df_zoom_heart_female,on='year', how='inner')
df_zoom_heart_merged=df_zoom_heart_merged[['DV_overall','DV_male','DV_female']]
df_zoom_heart_merged

# %%
#let's normalize this for a clearer and neater picture
x=df_zoom_heart_merged.values 
min_max_scaler = preprocessing.StandardScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_zoom_heart_merged_normalized = pd.DataFrame(x_scaled, columns=df_zoom_heart_merged.columns,index=df_zoom_heart_merged.index)
df_zoom_heart_merged_normalized

# %%
#better normalized plot of the heart deaths
ax = df_zoom_heart_merged_normalized.plot.bar(rot=0,color={"DV_overall": "green", "DV_male": "red", "DV_female":"blue"})

# %%
#another graph showing the heart deaths throughout the years
#we can see that deaths went up for males from 2015 onwards!
df_zoom_heart_merged_normalized_plot = pd.DataFrame({'Overall': df_zoom_heart_merged_normalized['DV_overall'],
                    'Male': df_zoom_heart_merged_normalized['DV_male'],
                       'Female': df_zoom_heart_merged_normalized['DV_female']}, index= df_zoom_heart_merged_normalized.index)
ax1 = df_zoom_heart_merged_normalized_plot.plot.line(rot=0,color={"Overall": "green", "Male": "red", "Female":"blue"})
ax1.xaxis.set_major_locator(plt.MaxNLocator(4))

# %%
# I would like to explore the deaths from heart failure, because those were increasing sharply from 2016
df_zoom_heart_failure.head()

# %%
#let's select all years
df_zoom_heart_failure_2010=df_zoom_heart_failure[(df_zoom_heart_failure['stratification1']=='Overall')&(df_zoom_heart_failure['year']==2010)].groupby('locationabbr').sum()
df_zoom_heart_failure_2011=df_zoom_heart_failure[(df_zoom_heart_failure['stratification1']=='Overall')&(df_zoom_heart_failure['year']==2011)].groupby('locationabbr').sum()
df_zoom_heart_failure_2012=df_zoom_heart_failure[(df_zoom_heart_failure['stratification1']=='Overall')&(df_zoom_heart_failure['year']==2012)].groupby('locationabbr').sum()
df_zoom_heart_failure_2013=df_zoom_heart_failure[(df_zoom_heart_failure['stratification1']=='Overall')&(df_zoom_heart_failure['year']==2013)].groupby('locationabbr').sum()
df_zoom_heart_failure_2014=df_zoom_heart_failure[(df_zoom_heart_failure['stratification1']=='Overall')&(df_zoom_heart_failure['year']==2014)].groupby('locationabbr').sum()
df_zoom_heart_failure_2015=df_zoom_heart_failure[(df_zoom_heart_failure['stratification1']=='Overall')&(df_zoom_heart_failure['year']==2015)].groupby('locationabbr').sum()
df_zoom_heart_failure_2016=df_zoom_heart_failure[(df_zoom_heart_failure['stratification1']=='Overall')&(df_zoom_heart_failure['year']==2016)].groupby('locationabbr').sum()
df_zoom_heart_failure_2017=df_zoom_heart_failure[(df_zoom_heart_failure['stratification1']=='Overall')&(df_zoom_heart_failure['year']==2017)].groupby('locationabbr').sum()
df_zoom_heart_failure_2018=df_zoom_heart_failure[(df_zoom_heart_failure['stratification1']=='Overall')&(df_zoom_heart_failure['year']==2018)].groupby('locationabbr').sum()

# %%
#let's look at the cases per 100,000 for each state for overall in the heart failure category
#except for 2018 where we don't have the whole data

df_zoom_heart_failure_cases_year=pd.DataFrame({'2010': df_zoom_heart_failure_2010['datavalue'],
                    '2011': df_zoom_heart_failure_2011['datavalue'],
                    '2012': df_zoom_heart_failure_2012['datavalue'],
                    '2013': df_zoom_heart_failure_2013['datavalue'],
                    '2014': df_zoom_heart_failure_2014['datavalue'],
                    '2015': df_zoom_heart_failure_2015['datavalue'],                   
                    '2016': df_zoom_heart_failure_2016['datavalue'],
                    '2017': df_zoom_heart_failure_2017['datavalue']}, index=df_zoom_heart_failure_2010.index)
ax1 = df_zoom_heart_failure_cases_year.plot.bar(rot=0,figsize=(40,15))

# %%
#taking another look at the whole data to check
pd.crosstab(df['locationabbr'], df['topic'])

# %%
#the messy graph above shows us some information, let's take a closer look using linear regression

lr=LinearRegression()
df_zoom_heart_failure_cases_year['slope']=np.nan
for i in range (df_zoom_heart_failure_cases_year.shape[0]):
    #x=[0,1,2,3,4]
    x=df_zoom_heart_failure_cases_year.columns[0:4]
    y=df_zoom_heart_failure_cases_year.iloc[i,0:4]
    lr.fit(x[:, np.newaxis],y)
    df_zoom_heart_failure_cases_year['slope'].iloc[i]=lr.coef_


#Now we can filter to those state that have a positive slope
df_zoom_heart_failure_cases_year_positive=df_zoom_heart_failure_cases_year[df_zoom_heart_failure_cases_year['slope']>0]
df_zoom_heart_failure_cases_year_positive.describe()

# %%
#let's graph the slope values, we can see that ME and IN and IA are the states with the highest slope. This indicates a sharp increase in heart failure deaths
#https://pandas.pydata.org/pandas-docs/version/0.15.1/visualization.html
df_zoom_heart_failure_cases_year_positive_half=df_zoom_heart_failure_cases_year_positive[df_zoom_heart_failure_cases_year_positive['slope']>2.0]
print(df_zoom_heart_failure_cases_year_positive_half)
df_zoom_heart_failure_cases_year_positive_half.drop('slope',axis=1,inplace=True)
ax1 = df_zoom_heart_failure_cases_year_positive_half.plot.bar(rot=0,figsize=(40,10))

# %% [markdown]
# # Leading Causes in the Unites States Data API https://data.cdc.gov/NCHS/NCHS-Leading-Causes-of-Death-United-States/bi63-dtpu

# %%
#df_leading_causes = pd.read_csv("NCHS-Leading_Causes_of_Death_United_States.csv")

# %%
response = requests.get('https://data.cdc.gov/resource/bi63-dtpu.json')    #https://data.cdc.gov/NCHS/NCHS-Leading-Causes-of-Death-United-States/bi63-dtpu
#response
results = response.json()
#results

# %%
#create dataframe
df_leading_causes = pd.read_json(json.dumps(results))
df_leading_causes

# %%
df_leading_causes.head()

# %%
df_leading_causes.shape

# %%
df_leading_causes.dtypes

# %%
df_leading_causes.columns

# %%
# #lowercase
# df_leading_causes.columns = [columns.lower().replace(' ', '_') for columns in df_leading_causes.columns]  
# df_leading_causes.columns

# %%
df_leading_causes.drop(['_113_cause_name'], axis=1,inplace=True)

# %%
df_leading_causes.year.nunique()

# %%
df_leading_causes.year

# %%
df_leading_causes.cause_name.nunique()

# %%
df_leading_causes.cause_name

# %%
print(df_leading_causes['year'].unique(), '\n')
print(df_leading_causes['cause_name'].unique())

# %% [markdown]
# # Map

# %%
Y=[]
for i in df_leading_causes['year'].unique():
    byyear = df_leading_causes.loc[(df_leading_causes['year']==i) & (df_leading_causes['cause_name']) & (df_leading_causes['deaths']), ['year','cause_name','deaths']]
    byyear = byyear['deaths'].sum()
    Y.append(byyear)
    
States = []
for i in df_leading_causes['state'].unique()[:50]:
    bystate = df_leading_causes.loc[(df_leading_causes['year']==2017) & (df_leading_causes['state']==i) & (df_leading_causes['cause_name']) & (df_leading_causes['deaths']), ['year','state','cause_name','deaths']]
    bystate = bystate['deaths'].sum()
    States.append(bystate)

len(States)
z = States

# %%
data = dict(
    type = 'choropleth', 
    locations = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"],
    locationmode = 'USA-states', 
    colorscale = [
        [1.0, 'rgb(180, 180, 180)'],
        [0, 'rgb(0, 0, 0)']
    ],
    text = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"], 
    z = z, 
    colorbar = {'title':'death total by state: 2017'}
)

layout = dict(geo = {'scope':'usa'})
choromap = go.Figure(data = [data],layout=layout)
iplot(choromap)

# %%
# US = df_leading_causes.loc[(df_leading_causes['year']) & (df_leading_causes['state']=='United States') & (df_leading_causes['deaths']) & (df_leading_causes['cause_name']), ['year','state' , 'deaths', 'cause_name']]
# US.head(10)
# US.sort_values(by=['year'])

# %%
#US.dtypes

# %%
#US.deaths = US.deaths.str.replace(',', '').astype(int)

# %%
#US.deaths

# %%
#US.dtypes

# %%
#US.year

# %% [markdown]
# # Linear Regression with K-Folds

# %%
#kFolds takes the linear regression model and randomly divides the dataset into 3 folds and then scores 
X = df_leading_causes[['year']]
y = df_leading_causes[['deaths']]
model = LinearRegression()
scores = []
kfold = KFold(n_splits=3, shuffle=True, random_state=1942)
for i, (train, test) in enumerate(kfold.split(X, y)):
 model.fit(X.iloc[train,:], y.iloc[train,:])
 score = model.score(X.iloc[test,:], y.iloc[test,:])
 scores.append(score)
print('R2 scores',scores)

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)

# plot it as in the example at http://scikit-learn.org/
plt.scatter(X, y,  color='red')
plt.plot(X, regr.predict(X), color='blue')
plt.xlabel('year')
plt.ylabel('deaths')
plt.show()

# %%
#define response variable
y = np.asarray(df_leading_causes['deaths'])

#define predictor variables
x = np.asarray(df_leading_causes['year'])

#add constant to predictor variables
x = sm.add_constant(x)

#fit linear regression model
model = sm.OLS(y, x).fit()

#view model summary
print(model.summary())

# %%
# data preprocessing
X = df_leading_causes[['year']] 

y = df_leading_causes['deaths']  

# train-test split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=1/3,random_state=1990)
 
# fitting the regression model
regressor = LinearRegression()
regressor.fit(X_train,y_train) 
 
# predicting the test set results
y_pred = regressor.predict(X_test) 
y_pred 
y_test
 
#plot for the TRAIN  
plt.scatter(X_train, y_train, color='red') 
plt.plot(X_train, regressor.predict(X_train), color='blue') 
plt.title("deaths vs year (training)") 
  
plt.xlabel("deaths") 
plt.ylabel("year") 
plt.show() 
 
#plot for TEST
plt.scatter(X_test, y_test, color='red') 
plt.plot(X_train, regressor.predict(X_train), color='blue') # plotting the regression line
plt.title("deaths vs year (Testing set)")
  
plt.xlabel("deaths") 
plt.ylabel("year") 
plt.show()

# %%
# df_lead_1 = df_leading_causes[(df_leading_causes['year']) & (df_leading_causes['deaths'])]

# # Plot line graph to show how the number of deaths changed over year.
# df_lead_1.sort_values(by=['year'], inplace=True)
# fig = px.line(x=df_lead_1['year'], y=df_lead_1['deaths'])
# fig.update_layout(title="number of deaths per year", xaxis_title="year", yaxis_title="number of deaths")
# fig.show()

# %%
# Sorting extracted data by 'Deaths' in descending order to show the cause name which attributed to highest number of deaths in 2016.
df_lead_2 = df_leading_causes[(df_leading_causes['year']==2017) & (df_leading_causes['cause_name']!='All causes')]
df_lead_2.sort_values(by=['deaths'], inplace=True, ascending=False)

# Plot bar graph to show how the number of deaths relate to cause of deaths.
fig=px.bar(x=df_lead_2['cause_name'], y=df_lead_2['deaths'])
fig.update_layout(title="number of deaths by causes in 2017", xaxis_title="cause name", yaxis_title="number of deaths")
fig.show()
df_lead_2

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df_leading_causes, nGraphShown, nGraphPerRow):
    nunique = df_leading_causes.nunique()
    df_leading_causes = df_leading_causes[[col for col in df_leading_causes if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df_leading_causes.shape
    columnNames = list(df_leading_causes)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df_leading_causes.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
plotPerColumnDistribution(df_leading_causes, 10, 5)

# %%
# Correlation matrix
def plotCorrelationMatrix(df_leading_causes, graphWidth):
    df_leading_causes = df_leading_causes.dropna('columns') # drop columns with NaN
    df_leading_causes = df_leading_causes[[col for col in df_leading_causes if df_leading_causes[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df_leading_causes.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df_leading_causes.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for Leading Causes', fontsize=15)
    plt.show()

# %%
plotCorrelationMatrix(df_leading_causes, 8)

# %%
# Scatter and density plots function
def plotScatterMatrix(df_leading_causes, plotSize, textSize):
    df_leading_causes = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df_leading_causes = df_leading_causes.dropna('columns')
    df_leading_causes = df_leading_causes[[col for col in df_leading_causes if df_leading_causes[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df_leading_causes)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df_leading_causes = df_leading_causes[columnNames]
    ax = pd.plotting.scatter_matrix(df_leading_causes, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df_leading_causes.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %%
#slow and does not show any insights
#plotScatterMatrix(df_leading_causes, 9, 10)

# %%
df_leading_causes_profile = pandas_profiling.ProfileReport(df_leading_causes)
df_leading_causes_profile

# %%
# https://pypi.org/project/sweetviz/
sweet_report = sv.analyze(df_leading_causes)
sweet_report.show_notebook(  w=None, 
                h=None, 
                scale=None,
                layout='widescreen',
                filepath=None)

# %% [markdown]
# # Another Analysis of a different source (NCHS)

# %%
df_nchs = pd.read_csv("NCHS-Leading_Causes_of_Death_United_States.csv")

# %%
df_nchs.shape

# %%
df_nchs.columns

# %%
#lowercase
df_nchs.columns = [columns.lower().replace(' ', '_') for columns in df_nchs.columns]  
df_nchs.columns

# %%
df_nchs.deaths

# %%
df_nchs.deaths = df_nchs.deaths.str.replace(',', '').astype(int)

# %%
df_nchs.deaths

# %%
df_nchs.drop(columns=['113_cause_name','age-adjusted_death_rate'], inplace=True)
df_nchs

# %%
df_nchs.isnull().values.sum()

# %%
# let's check the unique values in columns - Year, Cause Name, and State
print("\n Unique entries of years in column - Year: \n", df_nchs['year'].unique())
print("\n Unique entries of Causes of deaths in column - Cause Name: \n", df_nchs['cause_name'].unique())
print("\n Unique entries of State of country in column - State: \n", df_nchs['state'].unique())

# %%
# lets' plot a line graph to show how the number of deaths changed over the years

df_leading_1 = df_nchs[(df_nchs['cause_name']=='All causes') & (df_nchs['state']=='United States')]
df_leading_1.sort_values(by=['year'], inplace=True)
fig = px.line(x=df_leading_1['year'], y=df_leading_1['deaths'])
fig.update_layout(title="number of deaths per year", xaxis_title="year", yaxis_title="number of deaths")
fig.show()

# %%
# Sorting the extracted data by 'Deaths' in descending order to show the year in which the number of deaths is highest.
df_leading_1.sort_values(by=['deaths'],inplace=True, ascending=False)
df_leading_1

# %%
# Sorting the extracted data by Deaths in descending order to show the cause name which attributed to highest number of deaths in 2017
df_leading_2 = df_nchs[(df_nchs['year']==2017) & (df_nchs['state']=='United States') & (df_nchs['cause_name']!='All causes')]
df_leading_2.sort_values(by=['deaths'], inplace=True, ascending=False)

# let's plot a bar graph to show how the number of deaths relate to cause of deaths
fig=px.bar(x=df_leading_2['cause_name'], y=df_leading_2['deaths'])
fig.update_layout(title="number of deaths by causes in 2017", xaxis_title="cause name", yaxis_title="number of deaths")
fig.show()
df_leading_2

# %%
# Sorting the extracted data by Deaths in descending order to show the State in which the number of deaths is highest in 2017
df_leading_3 = df_nchs[(df_nchs['year']==2017) & (df_nchs['state']!='United States') & (df_nchs['cause_name']=='All causes')]
df_leading_3.sort_values(by=['deaths'], inplace=True, ascending=False)

# Plot bar graph to show how the number of deaths relate to each state in 2016.
fig=px.bar(x=df_leading_3['state'], y=df_leading_3['deaths'])
fig.update_layout(title="number of deaths by States in 2017", xaxis_title="state", yaxis_title="number of deaths")
fig.show()
df_leading_3

# %%
# Sorting the extracted data by Deaths in descending order to show the cause that attributed highest number of deaths
df_leading_4 = df_nchs[(df_nchs['state']=='United States') & (df_nchs['cause_name']!='All causes')]
df_leading_4.sort_values(by=['deaths'], inplace=True, ascending=False)

# Line plot of number of deaths over year
plt.figure(figsize=(10,12))
fig =sns.lineplot(data=df_leading_4, x='year', y='deaths', hue='cause_name', ci=None)
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0)
plt.xlabel('year',fontsize=10)
plt.ylabel('number of deaths',fontsize=10)
plt.title('number of deaths by cause over year',fontsize=12)

# print first 25 entries
df_leading_4[:25]

# %%
# Box plot to compare cause of deaths in detail
# Sorting extracted data by Deaths in descending order to show the cause that attributed highest number of deaths
# we can see that heart disease median is highest
df_leading_5 = df_nchs[(df_nchs['state']!='United States') & (df_nchs['cause_name']!='All causes') & (df_nchs['year']==2017)]
df_leading_5.sort_values(by=['deaths'], inplace=True, ascending=False)

fig = px.box(x=df_leading_5['cause_name'], y=df_leading_5['deaths'])
fig.update_layout(title="number of deaths by causes in 2017", xaxis_title="cause_name", yaxis_title="number of deaths")
fig.show()
df_leading_5

# %%
plt.figure(figsize=(16,9))
ax = sns.barplot(x="deaths", y ="cause_name", data=c)
ax.set(xlabel='deaths')
sns.despine(left=True, bottom=True)
plt.title("Top deaths from 2013 to 2017")
plt.show();

# %%
#this does not show much meaningful information
#plotPerColumnDistribution(df_nchs, 10, 5)

# %%
#this does not show much meaningful information
#plotCorrelationMatrix(df_nchs, 8)

# %%
#slow and does not show any new insight
#plotScatterMatrix(df_nchs, 9, 10)

# %%
sweet_report = sv.analyze(df_nchs)
sweet_report.show_notebook(  w=None, 
                h=None, 
                scale=None,
                layout='widescreen',
                filepath=None)

# %% [markdown]
# # Time Series Analysis Attempt

# %%
df_nchs.dtypes

# %%
df_nchs.isnull

# %%
df_nchs.fillna(df_nchs.mean())

# %%
df_nshs_numerical = df_nchs.select_dtypes(include=np.number)
df_nshs_numerical

# %%
df_nshs_numerical.year

# %%
df_nshs_numerical.year =  pd.to_datetime(df_nshs_numerical.year, format='%Y')
df_nshs_numerical

# %%
df_nshs_numerical = df_nshs_numerical.set_index('year')

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt
# import seaborn as sns
# import numpy as np
# sns.set()
# season = df_nshs_numerical
# season['year'] = df_nshs_numerical.year
# spivot = pd.pivot_table(season, index='year', values = 'deaths', aggfunc=np.mean)
# spivot.plot(figsize=(20,10), linewidth=3)
# plt.show()

# %%
y = df_nshs_numerical['deaths']
fig, ax = plt.subplots(figsize=(20, 6))
ax.plot(y,marker='.', linestyle='-', linewidth=0.5, label='year')
ax.plot(y.resample('M').mean(),marker='o', markersize=8, linestyle='-', label='Monthly Mean Resample')
ax.set_ylabel('deaths')
ax.legend();

# %%
# https://machinelearningmastery.com/make-predictions-time-series-forecasting-python/
# fit and evaluate an AR model
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error
import numpy
from math import sqrt
 
# create a difference transform of the dataset
def difference(df_nshs_numerical):
    diff = list()
    for i in range(1, len(df_nshs_numerical)):
        value = df_nshs_numerical[i] - df_nshs_numerical[i - 1]
        diff.append(value)
    return numpy.array(diff)
 
# Make a prediction give regression coefficients and lag obs
def predict(coef, history):
    yhat = coef[0]
    for i in range(1, len(coef)):
        yhat += coef[i] * history[-i]
    return yhat

# split dataset
X = difference(df_nshs_numerical.values)
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:]

# train autoregression
window = 5
model = AutoReg(train, lags=5)
model_fit = model.fit()
coef = model_fit.params

# walk forward over time steps in test
history = [train[i] for i in range(len(train))]
predictions = list()
for t in range(len(test)):
    yhat = predict(coef, history)
    obs = test[t]
    predictions.append(yhat)
    history.append(obs)
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')                   #graph  showing the actual observations in the test dataset (blue) compared to the predictions (red).
pyplot.show()

# %%
# data preprocessing
X = df_nchs[['year']] 

y = df_nchs['deaths']  

# train-test split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=1/3,random_state=1990)
 
# fitting the regression model
regressor = LinearRegression()
regressor.fit(X_train,y_train) 
 
# predicting the test set results
y_pred = regressor.predict(X_test) 
y_pred 
y_test
 
#plot for the TRAIN  
plt.scatter(X_train, y_train, color='red') 
plt.plot(X_train, regressor.predict(X_train), color='blue') 
plt.title("deaths vs year (training)") 
  
plt.xlabel("deaths") 
plt.ylabel("year") 
plt.show() 
 
#plot for TEST
plt.scatter(X_test, y_test, color='red') 
plt.plot(X_train, regressor.predict(X_train), color='blue') # plotting the regression line
plt.title("deaths vs year (Testing set)")
  
plt.xlabel("deaths") 
plt.ylabel("year") 
plt.show()

# %%
df_nchs_profile = pandas_profiling.ProfileReport(df_nchs)
df_nchs_profile

# %% [markdown]
# # Chronic disease indicators Cardiovascular Disease API   https://chronicdata.cdc.gov/Chronic-Disease-Indicators/U-S-Chronic-Disease-Indicators-Cardiovascular-Dise/232j-jiq5

# %%
response = requests.get('https://chronicdata.cdc.gov/resource/232j-jiq5.json')
#response
results = response.json()
#results

# %%
#create dataframe
df_cardio = pd.read_json(json.dumps(results))
df_cardio

# %%
df_cardio.columns

# %%
df_cardio.dtypes

# %%
df_cardio_profile = pandas_profiling.ProfileReport(df_cardio)
df_cardio_profile

# %%
sweet_report = sv.analyze(df_cardio)
sweet_report.show_notebook(  w=None, 
                h=None, 
                scale=None,
                layout='widescreen',
                filepath=None)
