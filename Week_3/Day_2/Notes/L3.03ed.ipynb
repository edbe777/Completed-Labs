# %%
print('hello world')
# Out:
# hello world

# %%
# THIS IS THE MOST IMPORTANT NOTEBOOK IN THIS COURSE

import pandas as pd
import math
import numpy as np

# %%
# reading a csv table into a variable
superstore = pd.read_csv("Sample - EU Superstore.csv")
# reading the excel table into a variable
orders = pd.read_excel("orders.xlsx")

# %%
display(superstore.head())
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       1  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 1       2  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 2       3  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 3       4  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 4       5  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
#
#   Customer ID   Customer Name    Segment   City    State         Country  \
# 0    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 1    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 2    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 3    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 4    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
#
#   Region       Product ID         Category Sub-Category  \
# 0  North  OFF-ST-10000988  Office Supplies      Storage
# 1  North  TEC-AC-10004144       Technology  Accessories
# 2  North  OFF-LA-10001915  Office Supplies       Labels
# 3  North  OFF-ST-10004550  Office Supplies      Storage
# 4  North  TEC-AC-10004068       Technology  Accessories
#
#                                  Product Name   Sales  Quantity  Discount  \
# 0                      Fellowes Folders, Blue   79.20         3       0.0
# 1           SanDisk Numeric Keypad, Bluetooth  388.92         7       0.0
# 2  Avery Legal Exhibit Labels, 5000 Label Set   35.19         3       0.0
# 3                Fellowes Folders, Wire Frame   50.94         2       0.0
# 4                    Memorex Memory Card, USB  307.44         3       0.0
#
#    Profit
# 0   39.60
# 1    0.00
# 2   16.11
# 3   13.20
# 4   73.71

# %% [markdown]
# # Slicing

# %%
# shows the first 5 rows of the table
superstore.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       1  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 1       2  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 2       3  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 3       4  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 4       5  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
#
#   Customer ID   Customer Name    Segment   City    State         Country  \
# 0    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 1    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 2    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 3    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
# 4    AS-10045  Aaron Smayling  Corporate  Leeds  England  United Kingdom
#
#   Region       Product ID         Category Sub-Category  \
# 0  North  OFF-ST-10000988  Office Supplies      Storage
# 1  North  TEC-AC-10004144       Technology  Accessories
# 2  North  OFF-LA-10001915  Office Supplies       Labels
# 3  North  OFF-ST-10004550  Office Supplies      Storage
# 4  North  TEC-AC-10004068       Technology  Accessories
#
#                                  Product Name   Sales  Quantity  Discount  \
# 0                      Fellowes Folders, Blue   79.20         3       0.0
# 1           SanDisk Numeric Keypad, Bluetooth  388.92         7       0.0
# 2  Avery Legal Exhibit Labels, 5000 Label Set   35.19         3       0.0
# 3                Fellowes Folders, Wire Frame   50.94         2       0.0
# 4                    Memorex Memory Card, USB  307.44         3       0.0
#
#    Profit
# 0   39.60
# 1    0.00
# 2   16.11
# 3   13.20
# 4   73.71

# %%
#shows the last 10 rows of the table
superstore.tail(10)
# Out:
#       Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 9990    9991  ES-2017-5488768  07/02/2017  10/02/2017     First Class
# 9991    9992  ES-2017-4951531  17/09/2017  21/09/2017    Second Class
# 9992    9993  ES-2017-2785118  14/04/2017  17/04/2017    Second Class
# 9993    9994  ES-2016-2993189  02/07/2016  08/07/2016  Standard Class
# 9994    9995  IT-2017-5726048  24/11/2017  27/11/2017    Second Class
# 9995    9996  ES-2014-3780358  16/11/2014  19/11/2014     First Class
# 9996    9997  ES-2015-5371207  25/01/2015  29/01/2015  Standard Class
# 9997    9998  ES-2015-5371207  25/01/2015  29/01/2015  Standard Class
# 9998    9999  ES-2015-5371207  25/01/2015  29/01/2015  Standard Class
# 9999   10000  ES-2015-5371207  25/01/2015  29/01/2015  Standard Class
#
#      Customer ID      Customer Name      Segment              City  \
# 9990    SN-20710       Steve Nguyen  Home Office       Northampton
# 9991    JF-15565         Jill Fjeld     Consumer           Preston
# 9992    JH-16180       Justin Hirsh     Consumer  Castelnau-le-Lez
# 9993    CR-12820        Cyra Reiten  Home Office           Avignon
# 9994    DK-12985     Darren Koutras     Consumer            Dublin
# 9995    CC-12100    Chad Cunningham  Home Office            Rovigo
# 9996    GB-14575  Giulietta Baptist     Consumer           Hamburg
# 9997    GB-14575  Giulietta Baptist     Consumer           Hamburg
# 9998    GB-14575  Giulietta Baptist     Consumer           Hamburg
# 9999    GB-14575  Giulietta Baptist     Consumer           Hamburg
#
#                                    State         Country   Region  \
# 9990                             England  United Kingdom    North
# 9991                             England  United Kingdom    North
# 9992  Languedoc-Roussillon-Midi-Pyrénées          France  Central
# 9993          Provence-Alpes-Côte d'Azur          France  Central
# 9994                              Dublin         Ireland    North
# 9995                              Veneto           Italy    South
# 9996                             Hamburg         Germany  Central
# 9997                             Hamburg         Germany  Central
# 9998                             Hamburg         Germany  Central
# 9999                             Hamburg         Germany  Central
#
#            Product ID         Category Sub-Category  \
# 9990  FUR-CH-10002373        Furniture       Chairs
# 9991  FUR-BO-10002003        Furniture    Bookcases
# 9992  OFF-PA-10001661  Office Supplies        Paper
# 9993  OFF-ST-10001255  Office Supplies      Storage
# 9994  OFF-AR-10000715  Office Supplies          Art
# 9995  OFF-BI-10000346  Office Supplies      Binders
# 9996  OFF-BI-10002083  Office Supplies      Binders
# 9997  OFF-SU-10003211  Office Supplies     Supplies
# 9998  TEC-PH-10001664       Technology       Phones
# 9999  OFF-AR-10001228  Office Supplies          Art
#
#                                    Product Name    Sales  Quantity  Discount  \
# 9990      Office Star Rocking Chair, Set of Two  429.480         3       0.0
# 9991             Sauder Classic Bookcase, Metal  870.900         2       0.0
# 9992  SanDisk Computer Printout Paper, 8.5 x 11  169.650         5       0.0
# 9993               Fellowes Trays, Single Width   51.678         1       0.1
# 9994                       Boston Markers, Blue   26.370         2       0.5
# 9995                  Ibico 3-Hole Punch, Clear   59.820         2       0.0
# 9996          Acco Hole Reinforcements, Economy    6.660         1       0.0
# 9997                          Acme Ruler, Steel   96.660         6       0.0
# 9998            Motorola Office Telephone, VoIP  502.950         7       0.0
# 9999               Stanley Markers, Water Color  152.280         6       0.0
#
#        Profit
# 9990   17.100
# 9991  130.620
# 9992   18.600
# 9993   22.968
# 9994   -4.770
# 9995   23.880
# 9996    0.570
# 9997   28.980
# 9998  221.130
# 9999   50.220

# %%
# this returns an iterable columns object
superstore.columns
list(superstore.columns)

#for col in superstore.columns            #don't need to cast to a list first, can use iteration method
    # do something with each column;
#    pass
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'City',
#  'State',
#  'Country',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit']

# %%
# this returns an iterable index object
superstore.index
#list(orders.index) 

#for rownum in superstore.index:
    #do something with a row
#    pass
#list(superstore.index)  #list with 10000 elements
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
# how can I slice one or more columns

# slicing one column
superstore["City"]           #this is a pandas series
# Out:
# 0         Leeds
# 1         Leeds
# 2         Leeds
# 3         Leeds
# 4         Leeds
#          ...
# 9995     Rovigo
# 9996    Hamburg
# 9997    Hamburg
# 9998    Hamburg
# 9999    Hamburg
# Name: City, Length: 10000, dtype: object

# %%
#Slicing multiple columns

superstore[['City', 'Country','Region']]
# Out:
#          City         Country   Region
# 0       Leeds  United Kingdom    North
# 1       Leeds  United Kingdom    North
# 2       Leeds  United Kingdom    North
# 3       Leeds  United Kingdom    North
# 4       Leeds  United Kingdom    North
# ...       ...             ...      ...
# 9995   Rovigo           Italy    South
# 9996  Hamburg         Germany  Central
# 9997  Hamburg         Germany  Central
# 9998  Hamburg         Germany  Central
# 9999  Hamburg         Germany  Central
#
# [10000 rows x 3 columns]

# %% [markdown]
# # Basic exploration & computation

# %%
#some useful column methods
# unique method of pandas 

#superstore['Country'].nunique()                 #like count(distinct Country) in SQL
#superstore['Country'].unique()              # distinct Country in SQL
superstore['Country'].value_counts(dropna=False)   #count(*) + group by Country in SQL, but group by does not handle NULL
# Out:
# France            2827
# Germany           2065
# United Kingdom    1633
# Italy             1108
# Spain              859
# Netherlands        435
# Austria            270
# Sweden             203
# Belgium            147
# Ireland            106
# Switzerland         78
# Portugal            70
# Norway              70
# Denmark             65
# Finland             64
# Name: Country, dtype: int64

# %%
# some useful column aggregations

# the sale with the highest value?
display(superstore['Sales'].max())

# what's the average sales value?
superstore[['Sales','Profit']].mean()
# Out:
# 7958.58
# Sales     293.808906
# Profit     37.282974
# dtype: float64

# %%
#on a Dataframe, a column aggregation function applies to all columns
superstore.max()
# Out:
# Row ID                                     10000
# Order ID                         IT-2017-5992832
# Order Date                            31/12/2017
# Ship Date                             31/12/2017
# Ship Mode                         Standard Class
# Customer ID                             ZD-21925
# Customer Name                 Zuschuss Donatelli
# Segment                              Home Office
# City                                      Zwolle
# State                                     Zürich
# Country                           United Kingdom
# Region                                     South
# Product ID                       TEC-PH-10004992
# Category                              Technology
# Sub-Category                              Tables
# Product Name     Xerox Parchment Paper, Recycled
# Sales                                    7958.58
# Quantity                                      14
# Discount                                    0.85
# Profit                                   3979.08
# dtype: object

# %%
# but only on the columns where it makes sense, only for numeric
#display(superstore.mean())
#superstore.median()
#superstore.mode()

# %%
#We can do computations over columns        #vector computation
#superstore['Sales']/superstore['Quantity']      #unit price for all 10000 columns, fastest way

#and store the result in a new column
#superstore['Unitary price'] = superstore['Sales']/superstore['Quantity']
#superstore[['Unitary price','Sales','Quantity']].head()

#we can also do comparisons
superstore['Large sale'] = superstore['Sales']>100            #result of comparison with number in sales column
superstore[['Large sale','Sales']].head()              #can use these true/false to filter out dataset
# Out:
#    Large sale   Sales
# 0       False   79.20
# 1        True  388.92
# 2       False   35.19
# 3       False   50.94
# 4        True  307.44

# %% [markdown]
# # Filtering & boolean masks

# %%
#a column like the one above (only True/False) is called a Boolean Mask
#Boolean masks are very useful to filter rows in DataFrames
superstore['Sales']>100                        #in SQL where sales>100 limit 5
superstore[superstore['Sales']>100].head()             #the first 5 rows for which the sales column has value > 100
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 1       2  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 4       5  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 5       6  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 6       7  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 7       8  ES-2015-5113958  02/08/2015  07/08/2015    Second Class
#
#   Customer ID   Customer Name    Segment           City    State  ...  \
# 1    AS-10045  Aaron Smayling  Corporate          Leeds  England  ...
# 4    AS-10045  Aaron Smayling  Corporate          Leeds  England  ...
# 5    AS-10045  Aaron Smayling  Corporate          Leeds  England  ...
# 6    AS-10045  Aaron Smayling  Corporate          Leeds  England  ...
# 7    EB-13840   Ellis Ballard  Corporate  West Bromwich  England  ...
#
#         Product ID         Category Sub-Category  \
# 1  TEC-AC-10004144       Technology  Accessories
# 4  TEC-AC-10004068       Technology  Accessories
# 5  OFF-ST-10002271  Office Supplies      Storage
# 6  TEC-PH-10003963       Technology       Phones
# 7  TEC-CO-10004325       Technology      Copiers
#
#                         Product Name   Sales Quantity  Discount  Profit  \
# 1  SanDisk Numeric Keypad, Bluetooth  388.92        7       0.0    0.00
# 4           Memorex Memory Card, USB  307.44        3       0.0   73.71
# 5        Rogers Shelving, Wire Frame  122.40        2       0.0   37.92
# 6    Apple Signal Booster, Full Size  413.82        3       0.0   20.61
# 7       Canon Personal Copier, Laser  428.22        3       0.0  192.69
#
#    Unitary price  Large sale
# 1          55.56        True
# 4         102.48        True
# 5          61.20        True
# 6         137.94        True
# 7         142.74        True
#
# [5 rows x 22 columns]

# %%
# do it yourself
# find the supersore line with the maximum sales
#display(superstore['Sales'].max())
#superstore[superstore['Sales']>7958].head()

superstore[superstore['Sales'] == superstore['Sales'].max()]
# Out:
#       Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 1774    1775  ES-2017-1651774  08/09/2017  14/09/2017  Standard Class
#
#      Customer ID  Customer Name    Segment   City    State  ...  \
# 1774    PJ-18835  Patrick Jones  Corporate  Prato  Tuscany  ...
#
#            Product ID         Category Sub-Category       Product Name  \
# 1774  OFF-AP-10004512  Office Supplies   Appliances  Hoover Stove, Red
#
#         Sales Quantity  Discount   Profit  Unitary price  Large sale
# 1774  7958.58       14       0.0  3979.08         568.47        True
#
# [1 rows x 22 columns]

# %%
#solution
superstore[superstore['Sales'] == superstore['Sales'].max()]
# Out:
#       Row ID         Order ID  Order Date  ...   Profit Unitary price Large sale
# 1774    1775  ES-2017-1651774  08/09/2017  ...  3979.08        568.47       True
#
# [1 rows x 22 columns]

# %%
#Boolean masks can also be combined by boolean operators (and, or, not), which in pandas are denoted by (&,|,~)
# | = or
# ~ = not
# & = and
# superstore['Large Sales'] = superstore['Sales']>superstore['Sales'].mean()
# superstore['Large Quantity'] =superstore['Quantity']>5
# superstore['Salesmean'] = superstore['Sales'].mean()

# superstore[['Sales','Quantity','Salesmean','Large Sales','Large Quantity']].head()

superstore['Large Quantity and Sales'] = (superstore['Quantity']>5) & (superstore['Sales']>superstore['Sales'].mean())
superstore['Large Quantity or Sales'] = (superstore['Quantity']>5) | (superstore['Sales']>superstore['Sales'].mean())
superstore['not Large Quantity'] = ~(superstore['Quantity']>5) 

superstore[['Sales','Quantity','Salesmean','Large Sales','Large Quantity','Large Quantity and Sales','Large Quantity or Sales','not Large Quantity']].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-4a4613d54c48> in <module>
#      13 superstore['not Large Quantity'] == ~(superstore['Quantity']>5)
#      14
# ---> 15 superstore[['Sales','Quantity','Salesmean','Large Sales','Large Quantity','Large Quantity and Sales','Large Quantity or Sales','not Large Quantity']].head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['Large Quantity', 'Salesmean', 'Large Sales'] not in index"

# %%
#This means these combinations can be used in filters as well
#superstore[(superstore['City']=='Lisbon')].head()
superstore[(superstore['City']=='Lisbon')&(superstore['Segment']=='Corporate')].head()
# Out:
#       Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 163      164  IT-2016-3695467  10/06/2016  14/06/2016  Standard Class
# 2759    2760  IT-2016-3432584  10/12/2016  15/12/2016  Standard Class
# 3217    3218  IT-2015-5223020  26/11/2015  02/12/2015  Standard Class
# 3218    3219  IT-2015-5223020  26/11/2015  02/12/2015  Standard Class
# 3219    3220  IT-2015-5223020  26/11/2015  02/12/2015  Standard Class
#
#      Customer ID     Customer Name    Segment    City   State  ...  \
# 163     SS-20140  Saphhira Shifley  Corporate  Lisbon  Lisboa  ...
# 2759    MY-17380   Maribeth Yedwab  Corporate  Lisbon  Lisboa  ...
# 3217    BB-11545     Brenda Bowman  Corporate  Lisbon  Lisboa  ...
# 3218    BB-11545     Brenda Bowman  Corporate  Lisbon  Lisboa  ...
# 3219    BB-11545     Brenda Bowman  Corporate  Lisbon  Lisboa  ...
#
#                             Product Name     Sales Quantity Discount  \
# 163                  Hoover Stove, White  3399.660       12      0.5
# 2759     Breville Coffee Grinder, Silver    93.915        3      0.5
# 3217         Avery 3-Hole Punch, Economy    27.870        2      0.5
# 3218   Cardinal Binding Machine, Economy   149.310        6      0.5
# 3219  Jiffy Business Envelopes, Recycled    45.900        5      0.5
#
#         Profit Unitary price  Large sale  Large Quantity and Sales  \
# 163  -3059.820       283.305        True                      True
# 2759   -18.855        31.305       False                     False
# 3217    -0.030        13.935       False                     False
# 3218   -65.790        24.885        True                     False
# 3219   -29.400         9.180       False                     False
#
#       Large Quantity or Sales  not Large Quantity
# 163                      True               False
# 2759                    False                True
# 3217                    False                True
# 3218                     True               False
# 3219                    False                True
#
# [5 rows x 25 columns]

# %%
# interview question -> what condition returns more rows? and conditon vs or condition
#or returns more because you only have to satisfy one of the conditions

# %% [markdown]
# # Binning

# %%
# how to perform binning -> bins on a variable

superstore['Sales']
# Out:
# 0        79.20
# 1       388.92
# 2        35.19
# 3        50.94
# 4       307.44
#          ...
# 9995     59.82
# 9996      6.66
# 9997     96.66
# 9998    502.95
# 9999    152.28
# Name: Sales, Length: 10000, dtype: float64

# %%
# this is the process of creating bins of a variable -> small boxes where you fit different ales values
"""
0 - 200 -> "low"
200 - 500 -> "medium"
501 - 1000 -> "high"
> 1000 -> "very high"
"""

# %%
# cut in 5 equally spaced bins
labels = ["Very Low", "Low", "Moderate", "High", "Very High"]
bins = pd.cut(superstore['Sales'],5, labels = labels)
bins.value_counts()
# Out:
# Very Low     9721
# Low           244
# Moderate       25
# High            8
# Very High       2
# Name: Sales, dtype: int64

# %%
#check result
display(superstore['Sales'].min())
display(superstore['Sales'].max())
print('size of bins = ', (superstore['Sales'].max()-superstore['Sales'].min())/5)
display(superstore[superstore['Sales']<1591.125+2.995].shape)
display(superstore[superstore['Sales']>7958.58-1591.125].shape)
# Out:
# 2.955
# 7958.58
# size of bins =  1591.125
# (9721, 28)
# (2, 28)

# %%
# qcut in 5 equaly filled bins. Why the imbalance? Repeated values
qbins = pd.qcut(superstore['Sales'],5, labels = labels)
qbins.value_counts()
# Out:
# Low          2004
# Very Low     2001
# Very High    2000
# High         2000
# Moderate     1995
# Name: Sales, dtype: int64

# %%
# cut in 5 designed bins
labels = ["Very Low", "Low", "Moderate", "High", "Very High"]
bins = pd.cut(superstore['Sales'],[0,10,100,1000,2000,6000], labels = labels)
bins.value_counts()
# Out:
# Moderate     4865
# Low          4359
# High          491
# Very High     156
# Very Low      127
# Name: Sales, dtype: int64

# %%
superstore['Sales'].hist()

# %%
# do it yourself: create 3 equally spaced bins for profit
display(superstore['Profit'])
display(superstore['Profit'].min())
display(superstore['Profit'].max())

# labels = ["Low", "Moderate", "High"]
# qbins = pd.qcut(superstore['Profit'],3, labels = labels)
# qbins.value_counts()

# do it yourself: create one bin for negative profit and 3 equally sized bins for positive profits
labels2 = ["Negative","Low", "Moderate", "High"]
qbins_profit2 = pd.qcut(superstore['Profit'],[min,0,max/3,2*max/3,max], labels = labels2)
qbins_profit2.value_counts()
# Out:
# 0        39.60
# 1         0.00
# 2        16.11
# 3        13.20
# 4        73.71
#          ...
# 9995     23.88
# 9996      0.57
# 9997     28.98
# 9998    221.13
# 9999     50.22
# Name: Profit, Length: 10000, dtype: float64
# -3059.82
# 3979.08
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-56f78f616c54> in <module>
#      10 # do it yourself: create one bin for negative profit and 3 equally sized bins for positive profits
#      11 labels2 = ["Negative","Low", "Moderate", "High"]
# ---> 12 qbins_profit2 = pd.qcut(superstore['Profit'],[min,0,max/3,2*max/3,max], labels = labels2)
#      13 qbins_profit2.value_counts()
#
# TypeError: unsupported operand type(s) for /: 'builtin_function_or_method' and 'int'

# %% [markdown]
# # Grouping

# %%
import numpy as np

# %%
# from a data analysis point of view there are two types of columns:

# - Dimensions -> categorical variables -> Segment, City, Country -> they cannot be aggregated using typical maths operators -> sum, doesnt work
# - Measures -> numerical variables -> can be aggregated

# We sometimes are able to turn measures into dimensions by binning e.g. low risk, medium, high, very high

# normally we represent measures as a function of dimensions -> sales per country, profit per state. This is done with group by

# %%
# Group by similar to SQL, but with a lot of flexibility
# groupby(the dimensions you want to group by).agg({measure(s) to aggregate: aggegation function(s)})

superstore.groupby(['Segment']).agg({'Sales':sum,'Order Date':min})

#alternatively, if we only have one column we can use the alternative syntax

superstore.groupby(['Segment'])['Sales'].agg(sum)

# grouped by dimensions become the new index!!

superstore.groupby(['Segment','State']).agg({'Sales':sum,'Order Date':min,'Customer ID':pd.Series.nunique}).head()
superstore.groupby(['Segment','State']).agg({'Sales':sum,'Order Date':min,'Customer ID':pd.Series.nunique})
# Out:
#                                                     Sales  Order Date  \
# Segment     State
# Consumer    Abruzzi                             3851.8800  04/06/2017
#             Alsace-Champagne-Ardenne-Lorraine  20664.8715  01/09/2015
#             Andalusía                          18270.4350  01/02/2016
#             Antwerp                             7899.0900  01/01/2016
#             Apulia                             12537.0000  02/02/2016
# ...                                                   ...         ...
# Home Office Valenciana                          7638.7290  02/12/2014
#             Veneto                               602.4120  04/08/2015
#             Vienna                             11763.0600  01/10/2017
#             Wales                               2453.0400  05/05/2015
#             Zürich                              1340.0400  01/11/2014
#
#                                                Customer ID
# Segment     State
# Consumer    Abruzzi                                      4
#             Alsace-Champagne-Ardenne-Lorraine           44
#             Andalusía                                   31
#             Antwerp                                      9
#             Apulia                                      23
# ...                                                    ...
# Home Office Valenciana                                  11
#             Veneto                                       5
#             Vienna                                      19
#             Wales                                        6
#             Zürich                                       2
#
# [319 rows x 3 columns]

# %%
#Multi-indexes can be hard to manage
#Tip, you can turn the index back into columns by using reset_index()
superstore.groupby(['Segment','State']).agg({'Sales':sum,'Order Date':min,'Customer ID':pd.Series.nunique}).reset_index().head()
# Out:
#     Segment                              State  ...  Order Date Customer ID
# 0  Consumer                            Abruzzi  ...  04/06/2017           4
# 1  Consumer  Alsace-Champagne-Ardenne-Lorraine  ...  01/09/2015          44
# 2  Consumer                          Andalusía  ...  01/02/2016          31
# 3  Consumer                            Antwerp  ...  01/01/2016           9
# 4  Consumer                             Apulia  ...  02/02/2016          23
#
# [5 rows x 5 columns]

# %%
# what if I want to define my own aggregation operation?
# you define your own aggregation function

def range_aggregation(x):
    return max(x) - min(x)

range_aggregation([2,4,6,8,10])
# Out:
# 8

# %%
# perform your usual group by, but then in the aggregation method, call the function you just defined
superstore.groupby('Segment')['Sales'].agg(range_aggregation)
superstore.groupby(['Segment','State']).agg({'Sales':range_aggregation,'Profit':range_aggregation}).reset_index().head()
# Out:
#     Segment                              State     Sales    Profit
# 0  Consumer                            Abruzzi  2882.460   141.240
# 1  Consumer  Alsace-Champagne-Ardenne-Lorraine  2945.424  2449.296
# 2  Consumer                          Andalusía  2176.230  1291.446
# 3  Consumer                            Antwerp  1611.150   549.120
# 4  Consumer                             Apulia  1505.310  1188.780

# %%
#do it yourself: find the average profitability and total Sales per shipping mode
superstore.groupby('Ship Mode')['Sales'].agg(np.mean)
superstore.groupby(['Ship Mode']).agg({'Sales':np.mean,'Profit':np.mean}).reset_index()
# Out:
#         Ship Mode       Sales     Profit
# 0     First Class  283.947009  32.107759
# 1        Same Day  318.928578  46.551137
# 2    Second Class  304.399577  36.584810
# 3  Standard Class  290.579683  37.963840

# %% [markdown]
# # Row operations - Apply

# %%
# We have seen we can make a function over all rows by combining columns
superstore['profit ratio'] = superstore['Profit']/superstore['Sales']
superstore.head()
# Out:
#    Row ID         Order ID  Order Date  ... Discount Profit profit ratio
# 0       1  ES-2017-1311038  07/02/2017  ...      0.0  39.60     0.500000
# 1       2  ES-2017-1311038  07/02/2017  ...      0.0   0.00     0.000000
# 2       3  ES-2017-1311038  07/02/2017  ...      0.0  16.11     0.457801
# 3       4  ES-2017-1311038  07/02/2017  ...      0.0  13.20     0.259128
# 4       5  ES-2017-1311038  07/02/2017  ...      0.0  73.71     0.239754
#
# [5 rows x 21 columns]

# %%
# what if I want to perform more complicated operations on the rows?
# I want to calculate if a row is not profitable (profit < 0), profitable (0=< profit < 100) or very profitable (profit>100)

# define a function that creates your logic
# the input will be the value of the profit of each row

def profitable(x):
    if x<0:
        return 'Not Profitable'
    elif x<100: 
        return 'Profitable'
    else:
        return 'Very Profitable'

profitable(-10)
# Out:
# 'Not Profitable'

# %%
# we have an option already
list(map(profitable,superstore['Profit']))
# Out:
# ['Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Very Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Not Profitable',
#  'Profitable',
#  'Very Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Profitable',
#  'Not Profitable',
#  'Profitable',
#  ...]

# %%
superstore['Profit'].apply(profitable)
# Out:
# 0            Profitable
# 1            Profitable
# 2            Profitable
# 3            Profitable
# 4            Profitable
#              ...
# 9995         Profitable
# 9996         Profitable
# 9997         Profitable
# 9998    Very Profitable
# 9999         Profitable
# Name: Profit, Length: 10000, dtype: object

# %%
#but we can use a more general method: apply
superstore['Profit-Flag'] = superstore['Profit'].apply(profitable)
superstore.head()

# the apply method, will apply the function given to each row in the dataframe, with the respective argument
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       1  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 1       2  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 2       3  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 3       4  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 4       5  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
#
#   Customer ID   Customer Name    Segment   City    State  ... Region  \
# 0    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...  North
# 1    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...  North
# 2    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...  North
# 3    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...  North
# 4    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...  North
#
#         Product ID         Category Sub-Category  \
# 0  OFF-ST-10000988  Office Supplies      Storage
# 1  TEC-AC-10004144       Technology  Accessories
# 2  OFF-LA-10001915  Office Supplies       Labels
# 3  OFF-ST-10004550  Office Supplies      Storage
# 4  TEC-AC-10004068       Technology  Accessories
#
#                                  Product Name   Sales  Quantity  Discount  \
# 0                      Fellowes Folders, Blue   79.20         3       0.0
# 1           SanDisk Numeric Keypad, Bluetooth  388.92         7       0.0
# 2  Avery Legal Exhibit Labels, 5000 Label Set   35.19         3       0.0
# 3                Fellowes Folders, Wire Frame   50.94         2       0.0
# 4                    Memorex Memory Card, USB  307.44         3       0.0
#
#    Profit  Profit-Flag
# 0   39.60   Profitable
# 1    0.00   Profitable
# 2   16.11   Profitable
# 3   13.20   Profitable
# 4   73.71   Profitable
#
# [5 rows x 21 columns]

# %%
# What if I want a function that uses data from multiple columns?
# For example I want to see if the dat between shipping and Ordering is larger than 7 days and flag the order as 'delayed' in that case

# use a function that take a whole row as an argument

#this is a good time to learn about dates and timestamps. You can find some info here:
#https://docs.python.org/3/library/datetime.html
from datetime import datetime
from datetime import timedelta

def delayed(row):
    delay = datetime.strptime(row['Ship Date'],'%d/%m/%Y')-datetime.strptime(row['Order Date'],'%d/%m/%Y')
    #essentially converts the date strings from the original table into internal time representations and computes the difference in times 
    
    if delay>timedelta(days=3):
        #Timedelta represent a period of x days
        return 'Delayed'
    else:
        return 'On-time'

# %%
#to run your function over all rows, you have to pass along the argument "axis=1"
superstore['Delayed?'] = superstore.apply(delayed, axis=1)
superstore.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       1  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 1       2  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 2       3  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 3       4  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 4       5  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
#
#   Customer ID   Customer Name    Segment   City    State  ...  \
# 0    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...
# 1    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...
# 2    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...
# 3    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...
# 4    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...
#
#         Product ID         Category Sub-Category  \
# 0  OFF-ST-10000988  Office Supplies      Storage
# 1  TEC-AC-10004144       Technology  Accessories
# 2  OFF-LA-10001915  Office Supplies       Labels
# 3  OFF-ST-10004550  Office Supplies      Storage
# 4  TEC-AC-10004068       Technology  Accessories
#
#                                  Product Name   Sales Quantity  Discount  \
# 0                      Fellowes Folders, Blue   79.20        3       0.0
# 1           SanDisk Numeric Keypad, Bluetooth  388.92        7       0.0
# 2  Avery Legal Exhibit Labels, 5000 Label Set   35.19        3       0.0
# 3                Fellowes Folders, Wire Frame   50.94        2       0.0
# 4                    Memorex Memory Card, USB  307.44        3       0.0
#
#    Profit  Profit-Flag  Delayed?
# 0   39.60   Profitable   Delayed
# 1    0.00   Profitable   Delayed
# 2   16.11   Profitable   Delayed
# 3   13.20   Profitable   Delayed
# 4   73.71   Profitable   Delayed
#
# [5 rows x 22 columns]

# %%
superstore['Delayed?'].value_counts()
# Out:
# Delayed    6854
# On-time    3146
# Name: Delayed?, dtype: int64

# %%
superstore['Ship Mode'].value_counts()
# Out:
# Standard Class    6054
# Second Class      1976
# First Class       1454
# Same Day           516
# Name: Ship Mode, dtype: int64

# %%
#do it yourself: create a function that categorizes an order as "Priority 1" if 
# - the Segment is Corporate and ship mode is First or Second Class
# - the ship mode is First Class
#and "Priority 2" otherwise 

def priority(x):
    if x['Ship Mode'] == 'First Class':
        return 'Priority 1'
    elif (x['Ship Mode']=='Second Class') and (x['Segment']== 'Corportate'):
        return 'Priority 1'
    else:
        return 'Priority 2'
# superstore['Priority-Flag'] = superstore['Segment'].apply(priority)
# superstore.head()
superstore['Priority-Flag'] = superstore.apply(priority, axis=1)
superstore.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       1  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 1       2  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 2       3  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 3       4  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
# 4       5  ES-2017-1311038  07/02/2017  11/02/2017  Standard Class
#
#   Customer ID   Customer Name    Segment   City    State  ...  \
# 0    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...
# 1    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...
# 2    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...
# 3    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...
# 4    AS-10045  Aaron Smayling  Corporate  Leeds  England  ...
#
#           Category Sub-Category                                Product Name  \
# 0  Office Supplies      Storage                      Fellowes Folders, Blue
# 1       Technology  Accessories           SanDisk Numeric Keypad, Bluetooth
# 2  Office Supplies       Labels  Avery Legal Exhibit Labels, 5000 Label Set
# 3  Office Supplies      Storage                Fellowes Folders, Wire Frame
# 4       Technology  Accessories                    Memorex Memory Card, USB
#
#     Sales Quantity Discount  Profit  Profit-Flag  Delayed?  Priority-Flag
# 0   79.20        3      0.0   39.60   Profitable   Delayed     Priority 2
# 1  388.92        7      0.0    0.00   Profitable   Delayed     Priority 2
# 2   35.19        3      0.0   16.11   Profitable   Delayed     Priority 2
# 3   50.94        2      0.0   13.20   Profitable   Delayed     Priority 2
# 4  307.44        3      0.0   73.71   Profitable   Delayed     Priority 2
#
# [5 rows x 23 columns]

# %%
superstore['Priority-Flag'].value_counts()
# Out:
# Priority 2    8546
# Priority 1    1454
# Name: Priority-Flag, dtype: int64

# %% [markdown]
# # Merging

# %%
# Merging is the way to cross information from multiple datasources.
#It is functionally the same as JOIN from SQL, even in the names of the methods
returns = pd.read_excel("Sample - EU Superstore.xlsx",sheet_name = "Returns")

# %%
returns.head()
# Out:
#           Order ID Returned
# 0  ES-2017-5389384      Yes
# 1  ES-2017-3638264      Yes
# 2  IT-2016-1498487      Yes
# 3  IT-2017-3941500      Yes
# 4  ES-2015-4840257      Yes

# %%
superstore.head()
# Out:
#    Row ID         Order ID  Order Date  ... profit ratio Profit-Flag Delayed?
# 0       1  ES-2017-1311038  07/02/2017  ...     0.500000  Profitable  On-time
# 1       2  ES-2017-1311038  07/02/2017  ...     0.000000  Profitable  On-time
# 2       3  ES-2017-1311038  07/02/2017  ...     0.457801  Profitable  On-time
# 3       4  ES-2017-1311038  07/02/2017  ...     0.259128  Profitable  On-time
# 4       5  ES-2017-1311038  07/02/2017  ...     0.239754  Profitable  On-time
#
# [5 rows x 23 columns]

# %%
#if we want details only on the returned orders
just_returned_details = pd.merge(left = superstore,
                                 right = returns,
                                 how = 'inner', 
                                 left_on = "Order ID", 
                                 right_on= "Order ID")
display(just_returned_details.shape)
just_returned_details.head()
# Out:
# (637, 24)
#    Row ID         Order ID  Order Date  ...      Profit-Flag Delayed? Returned
# 0      27  ES-2017-2557751  28/02/2017  ...  Very Profitable  On-time      Yes
# 1      28  ES-2017-2557751  28/02/2017  ...   Not Profitable  On-time      Yes
# 2      29  ES-2017-2557751  28/02/2017  ...       Profitable  On-time      Yes
# 3      60  ES-2016-4569090  29/08/2016  ...       Profitable  On-time      Yes
# 4      61  ES-2016-4569090  29/08/2016  ...   Not Profitable  On-time      Yes
#
# [5 rows x 24 columns]

# %%
# if we want to keep all orders, and just flag the returned ones, we can do a left merge same as left join
just_returned_addition = pd.merge(left = superstore,
                                  right = returns,
                                  how = 'left', 
                                  left_on = "Order ID", 
                                  right_on= "Order ID")
display(just_returned_addition.shape)
just_returned_addition.head()
# Out:
# (10000, 24)
#    Row ID         Order ID  Order Date  ... Profit-Flag Delayed? Returned
# 0       1  ES-2017-1311038  07/02/2017  ...  Profitable  On-time      NaN
# 1       2  ES-2017-1311038  07/02/2017  ...  Profitable  On-time      NaN
# 2       3  ES-2017-1311038  07/02/2017  ...  Profitable  On-time      NaN
# 3       4  ES-2017-1311038  07/02/2017  ...  Profitable  On-time      NaN
# 4       5  ES-2017-1311038  07/02/2017  ...  Profitable  On-time      NaN
#
# [5 rows x 24 columns]
