# %%
import json
import requests

# %%
response = requests.get('https://nova.bitcambio.com.br/api/v3/public/getassets')
#response
results = response.json()
#results

# %%
import pandas as pd

data = pd.DataFrame(results)
data.head(10)
# Out:
#    success message                                             result
# 0     True          {'Asset': 'AXS', 'AssetLong': 'Axie Infinity S...
# 1     True          {'Asset': 'BTC', 'AssetLong': 'Bitcoin', 'MinC...
# 2     True          {'Asset': 'DOGE', 'AssetLong': 'Dogecoin', 'Mi...
# 3     True          {'Asset': 'ETH', 'AssetLong': 'Ethereum', 'Min...
# 4     True          {'Asset': 'LTC', 'AssetLong': 'Litecoin', 'Min...
# 5     True          {'Asset': 'BRL', 'AssetLong': 'Real', 'MinConf...
# 6     True          {'Asset': 'USDT', 'AssetLong': 'Tether', 'MinC...

# %%
response = requests.get('https://nova.bitcambio.com.br/api/v3/public/getassets')

data = pd.DataFrame(response.json())
display(data.head())
data.shape
# Out:
#    success message                                             result
# 0     True          {'Asset': 'AXS', 'AssetLong': 'Axie Infinity S...
# 1     True          {'Asset': 'BTC', 'AssetLong': 'Bitcoin', 'MinC...
# 2     True          {'Asset': 'DOGE', 'AssetLong': 'Dogecoin', 'Mi...
# 3     True          {'Asset': 'ETH', 'AssetLong': 'Ethereum', 'Min...
# 4     True          {'Asset': 'LTC', 'AssetLong': 'Litecoin', 'Min...
# (7, 3)

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
dict(data['result'])
pd.DataFrame(dict(data['result']))
pd.DataFrame(dict(data['result'])).transpose()
# Out:
#   Asset            AssetLong MinConfirmation WithdrawTxFee  \
# 0   AXS  Axie Infinity Shard               4             0
# 1   BTC              Bitcoin               1        0.0003
# 2  DOGE             Dogecoin               2            10
# 3   ETH             Ethereum               4         0.006
# 4   LTC             Litecoin               2         0.001
# 5   BRL                 Real               1         10.99
# 6  USDT               Tether               4           0.1
#
#   WithdrawTxFeePercent SystemProtocol IsActive InfoMessage MaintenanceMode  \
# 0                    0       ETHERC20     True                       False
# 1                    0        BITCOIN     True                       False
# 2                    0        BITCOIN     True                       False
# 3                    0       ETHEREUM     True                       False
# 4                    0        BITCOIN     True                       False
# 5                 0.99           FIAT     True                       False
# 6                    0       ETHERC20     True                       False
#
#   MaintenanceMessage FormatPrefix FormatSufix DecimalSeparator  \
# 0                                                            .
# 1                              ฿                             .
# 2                                                            .
# 3                                                            .
# 4                                                            .
# 5                             R$                             ,
# 6                                                            .
#
#   ThousandSeparator DecimalPlaces withdrawal_fee_schedule
# 0                 ,             8
# 1                 ,             6
# 2                 ,             8
# 3                 ,             4
# 4                 ,             8
# 5                 .             2       fixed-and-percent
# 6                 ,             6

# %%
#---------------------------------------------------------second example-----------------------------------------------------------------------

# %%
response = requests.get('https://api.coinpaprika.com/v1/global')
response
results = response.json()
results
# Out:
# {'market_cap_usd': 2586847632403,
#  'volume_24h_usd': 243405517903,
#  'bitcoin_dominance_percentage': 41.85,
#  'cryptocurrencies_number': 5789,
#  'market_cap_ath_value': 3629384273801,
#  'market_cap_ath_date': '2021-10-27T07:40:00Z',
#  'volume_24h_ath_value': 536833814653206,
#  'volume_24h_ath_date': '2021-11-04T18:05:00Z',
#  'volume_24h_percent_from_ath': -99.95,
#  'volume_24h_percent_to_ath': 9999.99,
#  'market_cap_change_24h': 0.6,
#  'volume_24h_change_24h': 14.01,
#  'last_updated': 1637688226}

# %%
#---------------------------------------------------------third--------------------------------------------------

# %%
response = requests.get('http://hp-api.herokuapp.com/api/characters')
#response
results = response.json()
#results

# %%
import pandas as pd

data = pd.DataFrame(results)
data.head(10)
# Out:
#                  name alternate_names     species  gender       house  \
# 0        Harry Potter              []       human    male  Gryffindor
# 1    Hermione Granger              []       human  female  Gryffindor
# 2         Ron Weasley              []       human    male  Gryffindor
# 3        Draco Malfoy              []       human    male   Slytherin
# 4  Minerva McGonagall              []       human  female  Gryffindor
# 5      Cedric Diggory              []       human    male  Hufflepuff
# 6           Cho Chang              []       human  female   Ravenclaw
# 7       Severus Snape              []       human    male   Slytherin
# 8       Rubeus Hagrid              []  half-giant    male  Gryffindor
# 9  Neville Longbottom              []       human    male  Gryffindor
#
#   dateOfBirth yearOfBirth  wizard    ancestry eyeColour hairColour  \
# 0  31-07-1980        1980    True  half-blood     green      black
# 1  19-09-1979        1979    True  muggleborn     brown      brown
# 2  01-03-1980        1980    True  pure-blood      blue        red
# 3  05-06-1980        1980    True  pure-blood      grey     blonde
# 4  04-10-1925        1925    True                            black
# 5                    1977    True                  grey      brown
# 6                            True                 brown      black
# 7  09-01-1960        1960    True  half-blood     black      black
# 8  06-12-1928        1928    True  half-blood     black      black
# 9  30-07-1980        1980    True  pure-blood               blonde
#
#                                                 wand              patronus  \
# 0  {'wood': 'holly', 'core': 'phoenix feather', '...                  stag
# 1  {'wood': 'vine', 'core': 'dragon heartstring',...                 otter
# 2  {'wood': 'willow', 'core': 'unicorn tail-hair'...  Jack Russell terrier
# 3  {'wood': 'hawthorn', 'core': 'unicorn tail-hai...
# 4             {'wood': '', 'core': '', 'length': ''}             tabby cat
# 5  {'wood': 'ash', 'core': 'unicorn hair', 'lengt...
# 6             {'wood': '', 'core': '', 'length': ''}                  swan
# 7             {'wood': '', 'core': '', 'length': ''}                   doe
# 8          {'wood': 'oak', 'core': '', 'length': 16}
# 9  {'wood': 'cherry', 'core': 'unicorn tail-hair'...
#
#    hogwartsStudent  hogwartsStaff              actor alternate_actors  alive  \
# 0             True          False   Daniel Radcliffe               []   True
# 1             True          False        Emma Watson               []   True
# 2             True          False       Rupert Grint               []   True
# 3             True          False         Tom Felton               []   True
# 4            False           True  Dame Maggie Smith               []   True
# 5             True          False   Robert Pattinson               []  False
# 6             True          False        Katie Leung               []   True
# 7            False           True       Alan Rickman               []  False
# 8            False           True    Robbie Coltrane               []   True
# 9             True          False      Matthew Lewis               []   True
#
#                                                image
# 0       http://hp-api.herokuapp.com/images/harry.jpg
# 1   http://hp-api.herokuapp.com/images/hermione.jpeg
# 2         http://hp-api.herokuapp.com/images/ron.jpg
# 3       http://hp-api.herokuapp.com/images/draco.jpg
# 4  http://hp-api.herokuapp.com/images/mcgonagall.jpg
# 5      http://hp-api.herokuapp.com/images/cedric.png
# 6         http://hp-api.herokuapp.com/images/cho.jpg
# 7       http://hp-api.herokuapp.com/images/snape.jpg
# 8      http://hp-api.herokuapp.com/images/hagrid.png
# 9     http://hp-api.herokuapp.com/images/neville.jpg

# %%
response = requests.get('http://hp-api.herokuapp.com/api/characters')

data = pd.DataFrame(response.json())
display(data.head())
data.shape
# Out:
#                  name alternate_names species  gender       house dateOfBirth  \
# 0        Harry Potter              []   human    male  Gryffindor  31-07-1980
# 1    Hermione Granger              []   human  female  Gryffindor  19-09-1979
# 2         Ron Weasley              []   human    male  Gryffindor  01-03-1980
# 3        Draco Malfoy              []   human    male   Slytherin  05-06-1980
# 4  Minerva McGonagall              []   human  female  Gryffindor  04-10-1925
#
#   yearOfBirth  wizard    ancestry eyeColour hairColour  \
# 0        1980    True  half-blood     green      black
# 1        1979    True  muggleborn     brown      brown
# 2        1980    True  pure-blood      blue        red
# 3        1980    True  pure-blood      grey     blonde
# 4        1925    True                            black
#
#                                                 wand              patronus  \
# 0  {'wood': 'holly', 'core': 'phoenix feather', '...                  stag
# 1  {'wood': 'vine', 'core': 'dragon heartstring',...                 otter
# 2  {'wood': 'willow', 'core': 'unicorn tail-hair'...  Jack Russell terrier
# 3  {'wood': 'hawthorn', 'core': 'unicorn tail-hai...
# 4             {'wood': '', 'core': '', 'length': ''}             tabby cat
#
#    hogwartsStudent  hogwartsStaff              actor alternate_actors  alive  \
# 0             True          False   Daniel Radcliffe               []   True
# 1             True          False        Emma Watson               []   True
# 2             True          False       Rupert Grint               []   True
# 3             True          False         Tom Felton               []   True
# 4            False           True  Dame Maggie Smith               []   True
#
#                                                image
# 0       http://hp-api.herokuapp.com/images/harry.jpg
# 1   http://hp-api.herokuapp.com/images/hermione.jpeg
# 2         http://hp-api.herokuapp.com/images/ron.jpg
# 3       http://hp-api.herokuapp.com/images/draco.jpg
# 4  http://hp-api.herokuapp.com/images/mcgonagall.jpg
# (291, 19)

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
dict(data['wand'])
pd.DataFrame(dict(data['wand']))
pd.DataFrame(dict(data['wand'])).transpose()
# Out:
#          wood                core length
# 0       holly     phoenix feather     11
# 1        vine  dragon heartstring
# 2      willow   unicorn tail-hair     14
# 3    hawthorn   unicorn tail-hair     10
# 4
# ..        ...                 ...    ...
# 286
# 287
# 288
# 289
# 290
#
# [291 rows x 3 columns]

# %%
#---------------------------------------------------fourth-----------------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'http://www.boredapi.com/api/activity/'
response = requests.get(url)
# response.status_code 
df = pd.DataFrame([response.json()])
df
# Out:
#                 activity        type  participants  price link      key  \
# 0  Start a daily journal  relaxation             1      0       8779876
#
#    accessibility
# 0              0

# %%
#-----------------------------------------fifth-------------------------------------------------------------------------------------

# %%
# AirVisual	Air quality and weather data
response = requests.get('http://api.airvisual.com/v2/nearest_city?key=565969c5-96df-413c-ad4d-262dce5488e3')
response
results = response.json()
results
# Out:
# {'status': 'success',
#  'data': {'city': 'Munich',
#   'state': 'Bavaria',
#   'country': 'Germany',
#   'location': {'type': 'Point', 'coordinates': [11.647598, 48.16939800000001]},
#   'current': {'weather': {'ts': '2021-11-23T19:00:00.000Z',
#     'tp': 0,
#     'pr': 1029,
#     'hu': 90,
#     'ws': 2.41,
#     'wd': 84,
#     'ic': '02n'},
#    'pollution': {'ts': '2021-11-23T17:00:00.000Z',
#     'aqius': 37,
#     'mainus': 'p2',
#     'aqicn': 14,
#     'maincn': 'n2'}}}}

# %%
flattened_data = pd.json_normalize(results)
flattened_data
# Out:
#     status data.city data.state data.country data.location.type  \
# 0  success    Munich    Bavaria      Germany              Point
#
#         data.location.coordinates   data.current.weather.ts  \
# 0  [11.647598, 48.16939800000001]  2021-11-23T19:00:00.000Z
#
#    data.current.weather.tp  data.current.weather.pr  data.current.weather.hu  \
# 0                        0                     1029                       90
#
#    data.current.weather.ws  data.current.weather.wd data.current.weather.ic  \
# 0                     2.41                       84                     02n
#
#   data.current.pollution.ts  data.current.pollution.aqius  \
# 0  2021-11-23T17:00:00.000Z                            37
#
#   data.current.pollution.mainus  data.current.pollution.aqicn  \
# 0                            p2                            14
#
#   data.current.pollution.maincn
# 0                            n2
